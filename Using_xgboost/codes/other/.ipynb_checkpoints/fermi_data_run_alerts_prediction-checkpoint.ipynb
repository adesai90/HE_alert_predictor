# %% [markdown]
# ## Code Description:
#
# This code will use the downloaded Fermi LAT lightcurves from the LC repository to find number of alerts per year based on flux limits.

# %%
import os,sys
import numpy as np
import pandas as pd
import pyLCR
from astropy.io import fits
import pickle
import datetime
from codes_from_pylcr import *

import joblib
import glob
import matplotlib.pyplot as plt

# For training:
import xgboost as xgb

# %%
os.chdir('/Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Fermi_Sample/')

# %% [markdown]
# ### Note that this code uses the Fermi LC saved as a pickle file in the following format:
#   [array1],[array2],[array3],[array4]
# -  array1 = [timebins_detections,flux] --------------> xvals = timebins_detections
# -  array2 = [x_errors,np.transpose(flux_error)]------> xvals = timebins_detections
# -  array3 = [timebins_upperlimits,flux_upper_limit]--> xvals = timebins_upperlimits
# -  array4 = [timebins,ts] ----------------------------> xvals = timebins
# -  array5 = indices for detections only!

# %%
saved_fermi_lcs = glob.glob(f'lc_downloaded_data/*.pickle')

# %%
all_info = []
src_names = []
for indi_i_val in range(len(saved_fermi_lcs)):
    with open(saved_fermi_lcs[indi_i_val], 'rb') as handle:
        loaded_fermi_lc = pickle.load(handle)

    
    det_times=loaded_fermi_lc[0][0]
    det_flux_no_ul=loaded_fermi_lc[0][1]
    det_indices = loaded_fermi_lc[4]
    all_info.append([det_times,det_flux_no_ul,det_indices])
    src_names.append(saved_fermi_lcs[indi_i_val][-24:-7])

# %% [markdown]
# Now for each source we find a baseline flux. To find this we can get the minimum flux from each source.
#
# After that an assumption is taken that minimum flux times (some factor) constitues an alert

# %%
min_flux_values = []
for indi_arr in all_info:
    min_flux_values.append(np.amin(indi_arr[1]))

# %%
flux_factor_for_alert = 50

# %%
time_bins_yearly = [54466, #Jan 2008
                    54832, #Jan 2009 (leap)
                    55197, #Jan 2010
                    55562, #Jan 2011
                    55927, #Jan 2012
                    56293, #Jan 2013 (leap)
                    56658, #Jan 2014
                    57023, #Jan 2015
                    57388, #Jan 2016
                    57754, #Jan 2017 (leap)
                    58119, #Jan 2018
                    58484, #Jan 2019
                    58849, #Jan 2020
                    59215, #Jan 2021 (leap)
                    59580, #Jan 2022
                    59945, #Jan 2023
                    60310, #Jan 2024
                    60676, #Jan 2025 (leap)
                    61041] #Jan 2026

print(f'There are total number of {len(time_bins_yearly)-1} year bins')
# Out:
# There are total number of 18 year bins

# %%
alerts_per_bin = []
num_alerts_per_bin = []
for src_index in range(len(src_names)):
    alerts_per_indi_bin=[]
    num_alerts_per_indi_bin=[]
    times=[]
    fluxes=[]
    indices=[]
    for mjd_index in range(len(time_bins_yearly)):
        if mjd_index==len(time_bins_yearly)-1:
            continue
        tmin = time_bins_yearly[mjd_index]
        tmax = time_bins_yearly[mjd_index+1]
        allowed_indices = (all_info[src_index][0] > tmin) & (all_info[src_index][0] < tmax) & (all_info[src_index][1] > flux_factor_for_alert*min_flux_values[src_index])
        for indi_time in all_info[src_index][0][allowed_indices]:
            times.append(indi_time)
        for indi_flux in all_info[src_index][1][allowed_indices]:
            fluxes.append(indi_flux)
        for indi_index in all_info[src_index][2][allowed_indices]:
            indices.append(indi_index)
        num_alerts_per_indi_bin.append(len(all_info[src_index][0][allowed_indices]))
    alerts_per_bin.append([times,fluxes,indices])
    num_alerts_per_bin.append(num_alerts_per_indi_bin)

# %%
# Check 1 : Lets see the num alerts per time bin
"""
xvals = np.arange(1,19,1)
for src_index in range(len(src_names)):
    fig = plt.figure(figsize=(5,5))
    plt.plot(xvals,num_alerts_per_bin[src_index])
    plt.show()
    plt.close()
"""
# Out:
# '\nxvals = np.arange(1,19,1)\nfor src_index in range(len(src_names)):\n    fig = plt.figure(figsize=(5,5))\n    plt.plot(xvals,num_alerts_per_bin[src_index])\n    plt.show()\n    plt.close()\n'

# %%
if os.path.isdir(f'alerts_per_year_flux_factor_{flux_factor_for_alert}')!=True:
    os.mkdir(f'alerts_per_year_flux_factor_{flux_factor_for_alert}')

for src_index in range(len(src_names)):
    save_file = f'alerts_per_year_flux_factor_{flux_factor_for_alert}/num_alerts_per_year_file_{src_names[src_index]}.npy'
    np.save(save_file,num_alerts_per_bin[src_index])
    save_file2 = f'alerts_per_year_flux_factor_{flux_factor_for_alert}/alerts_flux_data_per_year_file_{src_names[src_index]}.npy'
    np.save(save_file2,alerts_per_bin[src_index])

# %% [markdown]
# # Starting prediction!

# %%
# Make new feature files or sue old ones:
make_feature_files=True

# Set Debug Flag
debug_this=False

xvals = np.arange(1,19,1)

# %%
for src_index in range(len(src_names)):
    if make_feature_files==False:
        continue
    
    all_times=xvals
    all_num_alerts=num_alerts_per_bin[src_index]
    
    df = pd.DataFrame.from_records(np.transpose([all_times,np.asarray(all_num_alerts)]), columns=['#MJD','n_alerts'])
    df.set_index('#MJD', inplace=True) #This replaces the index with the MJD value

    if debug_this==True:
        # Display the DataFrame
        df.plot(figsize=(10,5))
    
    batch_df = pd.DataFrame()

    # Lagging features
    batch_df['lag_1'] = df['n_alerts'].shift(1) # Prediction 0 Use numdays: 1 day 0-1 = 1
    batch_df['lag_4'] = df['n_alerts'].shift(4) # Prediction 3 Use numdays: 7 day 3-7 = 4
    batch_df['lag_5'] = df['n_alerts'].shift(5) # Prediction 2 Use numdays: -7 day 2-7 = 5
    batch_df['lag_6'] = df['n_alerts'].shift(6) # Prediction 1 Use numdays: -7 day 1-7 = 6

    batch_df['lag_11'] = df['n_alerts'].shift(11) # Prediction 3 Use numdays: -14 day 3-14 = 11
    batch_df['lag_12'] = df['n_alerts'].shift(12) # Prediction 2 Use numdays: -14 day 2-14 = 12
    batch_df['lag_13'] = df['n_alerts'].shift(13) # Prediction 1 Use numdays: -14 day 1-14 = 13


    # Rolling statistics
    batch_df['rolling_mean_7'] = df['n_alerts'].rolling(window=7).mean().round(2)
    batch_df['rolling_std_7'] = df['n_alerts'].rolling(window=7).std().round(2)

    # Inspect target variable - it's actually 3!

    # Lagging target variable
    batch_df['target_1d'] = df['n_alerts'].shift(-1) # Next day
    batch_df['target_2d'] = df['n_alerts'].shift(-2) # Second-next day
    batch_df['target_3d'] = df['n_alerts'].shift(-3) # Third-next day

    # Run predictions with all three models

    predictions_ls = [] # list to store predictions
    batch_df = batch_df.dropna()

    corr = batch_df.corr()
    corr.style.background_gradient(cmap='coolwarm')
    features_df = batch_df[["lag_1", "lag_4", "lag_5", "lag_6", "lag_11", "lag_12", "lag_13", "rolling_mean_7", "rolling_std_7"]] 
    # Directory for feature store
    directory = "feature_store"
    if not os.path.exists(directory):
        os.makedirs(directory)


    id = "v1"
    features_df.to_csv(f'{directory}/{src_names[src_index]}_features_{id}.csv')
    #targets_df = batch_df[["target_1d", "target_2d", "target_3d", "target_9d"]] 
    targets_df = batch_df[["target_1d", "target_2d", "target_3d"]] 
    targets_df.to_csv(f'{directory}/{src_names[src_index]}_targets_{id}.csv')

# %%
# Use the marker to seperate of the data for learning and prediction:
#leave_number_indices = -40

# Make new feature files or sue old ones:
make_training_files=True

# %%
leave_number_indices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 leave_number_indices
#
# NameError: name 'leave_number_indices' is not defined

# %%
def train_model(fermi_lc_file,directory,id):

    
    X_train = pd.read_csv(f'{directory}/{fermi_lc_file}_features_{id}.csv')
    X_train.set_index('#MJD', inplace=True) #This replaces the index with the MJD value
    leave_number_indices = 2
    print(len(X_train))
    X_train_mod = X_train.head(leave_number_indices) # save some rows for later
    X_train_mod

    targets_df = pd.read_csv(f'{directory}/{fermi_lc_file}_targets_{id}.csv')
    targets_df.set_index('#MJD', inplace=True) #This replaces the index with the MJD value
    targets_df_mod = targets_df.head(leave_number_indices) # save some rows for later 
    targets_df_mod

    # turn into a list
    y_train_ls= []
    for target in targets_df_mod.columns:
      y_train_ls.append(targets_df_mod[target])

    # Loop through targets - train one model for each target variable
    cv_results_ls = []
    for y_train in y_train_ls:

      # Prepare the DMatrix which is required by XGBoost
      dtrain = xgb.DMatrix(data=X_train_mod, label=y_train)

      # Define XGBoost parameters
      params = {
        #'max_depth': 6,
        #'min_child_weight': 1,
        'eta': 0.01,
        #'subsample': 1,
        #'colsample_bytree': 1,
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse'
      }

      # Perform cross-validation
      cv_results = xgb.cv(
          params=params,
          dtrain=dtrain,
          num_boost_round=100,
          early_stopping_rounds=5,
          metrics='rmse',
          as_pandas=True,
          seed=123
      )
      cv_results_ls.append(cv_results)
      # Show the last mean RMSE as a measure of final performance
      print(f"Last mean RMSE: {cv_results['test-rmse-mean'][-1:]}")

    if debug_this==True:
      plt.figure(figsize=(10, 6))

      for idx, cv_results in enumerate(cv_results_ls):
          plt.plot(cv_results['test-rmse-mean'], label=f'CV Run {idx+1}')

      plt.title('Test RMSE Through Iterations')
      plt.xlabel('Number of Boosting Rounds')
      plt.ylabel('Mean RMSE')
      plt.legend()
      plt.show()

    # List to store the final models
    final_models_ls = []

    # Use the same params here you used in cross-validation
    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse'
      }

    # Iterate through each set of cross-validation results and corresponding training targets
    for cv_results, y_train in zip(cv_results_ls, y_train_ls):
        # Determine the optimal number of boosting rounds from cross-validation results
        optimal_boost_rounds = cv_results['test-rmse-mean'].idxmin() + 1

        # Initialize the XGBoost regressor with determined parameters
        final_model = xgb.XGBRegressor(
            n_estimators=optimal_boost_rounds,
            **params
        )

        # Train the model on the full training dataset
        final_model.fit(X_train_mod, y_train)

        # Append the trained model to the list
        final_models_ls.append(final_model)


    if os.path.isdir('models')!=True:
        os.mkdir('models')
    #os.mkdir('models')
    # Save each model with a unique filename
    for idx, final_model in enumerate(final_models_ls):
        filename = f'models/{fermi_lc_file}_batch_demand_forecaster_model_{idx+1}.pkl'  # Create a unique filename for each model
        joblib.dump(final_model, filename)
    del dtrain,cv_results
    print("Ran!")
    return

# %%
for indi_i_val in range(len(saved_fermi_lcs)):
    if make_training_files==False:
        continue
    id = "v1"
    a = train_model(saved_fermi_lcs[indi_i_val][-24:-7],directory,id)
# Out:
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    16.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    17.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    15.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    11.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    11.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    14.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    22.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    15.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    10.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    15.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    18.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    12.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    13.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    11.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    12.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    10.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    14.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    19.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    17.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    10.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# ...
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    14.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    10.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    10.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    6.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    12.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    12.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    24.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    10.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    16.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    12.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    13.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    9.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    14.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    11.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    5.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    6.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    2.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    10.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    8.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    7.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.0
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    1.333333
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    4.0
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    3.333333
# Name: test-rmse-mean, dtype: float64
# Ran!
# 2
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Last mean RMSE: 0    0.666667
# Name: test-rmse-mean, dtype: float64
# Ran!

# %% [markdown]
# # Now we Predict!

# %%
# Run predictions with all three models

for indi_i_val in range(len(saved_fermi_lcs)):
    predictions_ls = [] # list to store predictions
    #if indi_i_val!=0:
    #    continue

    
    for idx in range(1, 4):  # Assuming there are 3 models
        filename = f'models/{saved_fermi_lcs[indi_i_val][-24:-7]}_batch_demand_forecaster_model_{idx}.pkl'  # Create a unique filename for each model
        model = joblib.load(filename)
        prediction = model.predict(features_df)
        predictions_ls.append(prediction)
    # Let's compare to the true values!

    targets_df = pd.read_csv(f'{directory}/{saved_fermi_lcs[indi_i_val][-24:-7]}_targets_{id}.csv')
    targets_df.set_index('#MJD', inplace=True) #This replaces the index with the MJD value

    predictions_df = pd.DataFrame({f'predicted_{i+1}d': predictions_ls[i] for i in range(len(predictions_ls))})
    predictions_df.index = features_df.index
    result_df = predictions_df.join(targets_df, how = "inner")
    #print(result_df)

# %%
import matplotlib as mpl

font = {'size'   : 25}
mpl.rc('font', **font)

# %%
def make_plot(saved_fermi_lcs_arr,directory,id_val,target_val,predicted_val,example_source="none"):
    for indi_i_val in range(len(saved_fermi_lcs_arr)):
        predictions_ls = [] # list to store predictions
        if example_source!="none":
            if example_source!=saved_fermi_lcs[indi_i_val][-24:][:-7]:
                continue

        features_df = pd.read_csv(f'{directory}/{saved_fermi_lcs_arr[indi_i_val][-24:-7]}_features_{id_val}.csv')
        features_df.set_index('#MJD', inplace=True) #This replaces the index with the MJD value
        if len(features_df)/3>=40:
            leave_number_indices = -40
        else:
            leave_number_indices = -1*int(len(features_df)/3)
        
        for idx in range(1, 4):  # Assuming there are 3 models
            filename = f'models/{saved_fermi_lcs_arr[indi_i_val][-24:-7]}_batch_demand_forecaster_model_{idx}.pkl'  # Create a unique filename for each model
            model = joblib.load(filename)
            prediction = model.predict(features_df)
            predictions_ls.append(prediction)
        # Let's compare to the true values!

        targets_df = pd.read_csv(f'{directory}/{saved_fermi_lcs_arr[indi_i_val][-24:-7]}_targets_{id_val}.csv')
        targets_df.set_index('#MJD', inplace=True) #This replaces the index with the MJD value

        predictions_df = pd.DataFrame({f'predicted_{i+1}d': predictions_ls[i] for i in range(len(predictions_ls))})
        predictions_df.index = features_df.index
        result_df = predictions_df.join(targets_df, how = "inner")
        #print(result_df)
    
        fig = plt.figure(figsize=(12,7),dpi=200)
        ax = plt.subplot()

        ax.plot(result_df.index.array,result_df[target_val].array,"-",color="grey",linewidth=3,label="Original Data")
        ax.plot(result_df.index.array,result_df[predicted_val].array,":",color="red",linewidth=2,label="Training+Predicted Data")
        ax.plot([result_df.index.array[leave_number_indices],result_df.index.array[leave_number_indices]],[-0.05,10.15],"--",color="blue")  #For example agnstorm

        plt.ticklabel_format(axis='both', style='plain', scilimits=(4,9))

    
        plt.text(result_df.index.array[int(-1*leave_number_indices/2)],9.5,"Training")  #For  example
        plt.text(result_df.index.array[leave_number_indices+3],9.5,"Prediction") #For  example

        plt.xlabel("Time (MJD)")
        plt.ylabel("Count rate")
    
        plt.ylim(-0.05,10.15) #For  example
        plt.xlim(result_df.index.array[0]-0.5,result_df.index.array[-1]+11) #For   example
        #ax.set_xticklabels([str(int(x)) for x in ax.get_xticks()])
        plt.legend()

        plt.savefig(f'predictions/{saved_fermi_lcs_arr[indi_i_val][-24:-7]}_{target_val}.pdf',bbox_inches="tight")

        if example_source=="none":
            plt.close()

# %%
# Making all points for 1 day targets:
make_plot(saved_fermi_lcs,directory,id,'target_1d','predicted_1d')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[97], line 2
#       1 # Making all points for 1 day targets:
# ----> 2 make_plot(saved_fermi_lcs,directory,id,'target_1d','predicted_1d')
#
# Cell In[95], line 41, in make_plot(saved_fermi_lcs_arr, directory, id_val, target_val, predicted_val, example_source)
#      37 plt.ticklabel_format(axis='both', style='plain', scilimits=(4,9))
#      40 plt.text(result_df.index.array[int(-1*leave_number_indices/2)],9.5,"Training")  #For  example
# ---> 41 plt.text(result_df.index.array[leave_number_indices+3],9.5,"Prediction") #For  example
#      43 plt.xlabel("Time (MJD)")
#      44 plt.ylabel("Count rate")
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:284, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     278 def __getitem__(
#     279     self,
#     280     key: PositionalIndexer2D,
#     281 ) -> Self | Any:
#     282     if lib.is_integer(key):
#     283         # fast-path
# --> 284         result = self._ndarray[key]
#     285         if self.ndim == 1:
#     286             return self._box_func(result)
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
# Making all points for 2 day targets:
make_plot(saved_fermi_lcs,directory,id,'target_2d','predicted_2d')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[98], line 2
#       1 # Making all points for 2 day targets:
# ----> 2 make_plot(saved_fermi_lcs,directory,id,'target_2d','predicted_2d')
#
# Cell In[95], line 41, in make_plot(saved_fermi_lcs_arr, directory, id_val, target_val, predicted_val, example_source)
#      37 plt.ticklabel_format(axis='both', style='plain', scilimits=(4,9))
#      40 plt.text(result_df.index.array[int(-1*leave_number_indices/2)],9.5,"Training")  #For  example
# ---> 41 plt.text(result_df.index.array[leave_number_indices+3],9.5,"Prediction") #For  example
#      43 plt.xlabel("Time (MJD)")
#      44 plt.ylabel("Count rate")
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:284, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     278 def __getitem__(
#     279     self,
#     280     key: PositionalIndexer2D,
#     281 ) -> Self | Any:
#     282     if lib.is_integer(key):
#     283         # fast-path
# --> 284         result = self._ndarray[key]
#     285         if self.ndim == 1:
#     286             return self._box_func(result)
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %%
# Making all points for 3 day targets:
make_plot(saved_fermi_lcs,directory,id,'target_3d','predicted_3d')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[99], line 2
#       1 # Making all points for 3 day targets:
# ----> 2 make_plot(saved_fermi_lcs,directory,id,'target_3d','predicted_3d')
#
# Cell In[95], line 41, in make_plot(saved_fermi_lcs_arr, directory, id_val, target_val, predicted_val, example_source)
#      37 plt.ticklabel_format(axis='both', style='plain', scilimits=(4,9))
#      40 plt.text(result_df.index.array[int(-1*leave_number_indices/2)],9.5,"Training")  #For  example
# ---> 41 plt.text(result_df.index.array[leave_number_indices+3],9.5,"Prediction") #For  example
#      43 plt.xlabel("Time (MJD)")
#      44 plt.ylabel("Count rate")
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/core/arrays/_mixins.py:284, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     278 def __getitem__(
#     279     self,
#     280     key: PositionalIndexer2D,
#     281 ) -> Self | Any:
#     282     if lib.is_integer(key):
#     283         # fast-path
# --> 284         result = self._ndarray[key]
#     285         if self.ndim == 1:
#     286             return self._box_func(result)
#
# IndexError: index 3 is out of bounds for axis 0 with size 2

# %% [markdown]
# ## Example
# To check an example, we will use one of the sources for which there exists a good amount of data.

# %%
# Making an example plot using 3 day targets for one source:
make_plot(saved_fermi_lcs,directory,id,'target_3d','predicted_3d',example_source="4FGL_J1058.6-8003")
