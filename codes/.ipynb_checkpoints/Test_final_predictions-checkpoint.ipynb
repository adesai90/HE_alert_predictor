# %%
from prediction_codes import *
from concurrent.futures import ProcessPoolExecutor

import glob

# %%
flux_factor_for_alert= 50 # Fixed for now
leave_number_indices=-6

# Note fixing path for my directory, please change this based on your installation
wdir = "/Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Main/Model_predictions/cache_folder/"
os.chdir(wdir)

num_alerts_files = glob.glob(f'../../Fermi_sample/alerts_per_year_flux_factor_{flux_factor_for_alert}/num_alerts_per_year_file_*')
alerts_per_bin_files = glob.glob(f'../../Fermi_sample/alerts_per_year_flux_factor_{flux_factor_for_alert}/alerts_flux_data_per_year_file_*')

print("Current working directory: ",os.getcwd())

src_names=[]
for path_name in num_alerts_files:
    src_names.append(path_name[-21:][:-4])


id_val = "v3"
# Out:
# Current working directory:  /Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Main/Model_predictions/cache_folder

# %%
for src_index in range(len(src_names)): 
    print(f"\n{'='*60}")
    print(f"Running {src_names[src_index]}")
    print(f"{'='*60}")
    src = src_names[src_index]
    model_type = 'flux'
    seed = 1
    
    save_directory = f'/Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Main/Model_predictions/predictions/seed_{seed}'

    
    try:
        # Load features
        feature_directory = f'{wdir}/feature_store_flux_factor_{flux_factor_for_alert}'
    
        features_df = pd.read_csv(f'{feature_directory}/{src}_{model_type}_features_{id_val}.csv')
        features_df.set_index('#MJD', inplace=True)
        #features_df = features_df.head(leave_number_indices)
        features_df = features_df.dropna()
            
        # Load targets
        targets_df = pd.read_csv(f'{feature_directory}/{src}_{model_type}_targets_{id_val}.csv')
        targets_df.set_index('#MJD', inplace=True)
        
            
        result_df = predictions_df.join(targets_df, how='inner')
        print(result_df)
            
        # Split train/test
        train_df = result_df.head(leave_number_indices)
        
        recursive_predictions = np.load(f'{save_directory}/seed_{seed}_fl_thresh_{flux_factor_for_alert}_{src}_{model_type}_recursive_predictions.npy')
        
        if model_type=='flux':
            # Plot training data
            ax.plot(train_df.index.values[1:], 10**(train_df[f'{model_type}_target_1d'].values[:-1]), "-o", 
                    color="blue", linewidth=2, markersize=4, label="Training Data", alpha=0.7)
        else:
            ax.plot(train_df.index.values[1:], train_df[f'{model_type}_target_1d'].values[:-1], "-o", 
                    color="blue", linewidth=2, markersize=4, label="Training Data", alpha=0.7)
            
        ax.plot(recursive_predictions[0], recursive_predictions[1], "--s", 
                color="red", linewidth=2, markersize=6, label="Predictions", alpha=0.9)   
            
        plt.xlabel("Time (MJD)", fontweight='bold')
        plt.ylabel(f"{model_type.capitalize()} Value", fontweight='bold')
        plt.title(f"{src} - {model_type.upper()} Prediction",fontweight='bold')
        plt.legend(loc='best')
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.yscale("log")
        
        plt.show()
    except Exception as e:
        print(f"ERROR processing {src} ({model_type}): {str(e)}")
        import traceback
        traceback.print_exc()
        continue
# Out:
# ============================================================
# Running 4FGL_J1418.4-0233
# ============================================================
# ERROR processing 4FGL_J1418.4-0233 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0118.3-6008
# ============================================================
# ERROR processing 4FGL_J0118.3-6008 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2207.5-5346
# ============================================================
# ERROR processing 4FGL_J2207.5-5346 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0152.2+3714
# ============================================================
# ERROR processing 4FGL_J0152.2+3714 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0001.5+2113
# ============================================================
# ERROR processing 4FGL_J0001.5+2113 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2005.1+7003
# ============================================================
# ERROR processing 4FGL_J2005.1+7003 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0433.6-6030
# ============================================================
# ERROR processing 4FGL_J0433.6-6030 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0958.7+6534
# ============================================================
# ERROR processing 4FGL_J0958.7+6534 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0713.8+1935
# ============================================================
# ERROR processing 4FGL_J0713.8+1935 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0212.9+2244
# ============================================================
# ERROR processing 4FGL_J0212.9+2244 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0941.7+4125
# ============================================================
# ERROR processing 4FGL_J0941.7+4125 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1830.1+0617
# ============================================================
# ERROR processing 4FGL_J1830.1+0617 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0505.3+0459
# ============================================================
# ERROR processing 4FGL_J0505.3+0459 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1438.9+3710
# ============================================================
# ERROR processing 4FGL_J1438.9+3710 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2253.9+1609
# ============================================================
# ERROR processing 4FGL_J2253.9+1609 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0218.9-2305
# ============================================================
# ERROR processing 4FGL_J0218.9-2305 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1037.7+5711
# ============================================================
# ERROR processing 4FGL_J1037.7+5711 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1310.5+3221
# ============================================================
# ERROR processing 4FGL_J1310.5+3221 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1304.3-4353
# ============================================================
# ERROR processing 4FGL_J1304.3-4353 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0338.9-2848
# ============================================================
# ERROR processing 4FGL_J0338.9-2848 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1825.1-5231
# ============================================================
# ERROR processing 4FGL_J1825.1-5231 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1315.9-0732
# ============================================================
# ERROR processing 4FGL_J1315.9-0732 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0812.6+2821
# ============================================================
# ERROR processing 4FGL_J0812.6+2821 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0931.9+6737
# ============================================================
# ERROR processing 4FGL_J0931.9+6737 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0256.3+0334
# ============================================================
# ERROR processing 4FGL_J0256.3+0334 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0730.3-1141
# ============================================================
# ERROR processing 4FGL_J0730.3-1141 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0644.6+6039
# ============================================================
# ERROR processing 4FGL_J0644.6+6039 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1109.6+3735
# ============================================================
# ERROR processing 4FGL_J1109.6+3735 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2318.2+1915
# ============================================================
# ERROR processing 4FGL_J2318.2+1915 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0243.4+7119
# ============================================================
# ERROR processing 4FGL_J0243.4+7119 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0650.5-2851
# ============================================================
# ERROR processing 4FGL_J0650.5-2851 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0700.5-6610
# ============================================================
# ERROR processing 4FGL_J0700.5-6610 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1323.9+1405
# ============================================================
# ERROR processing 4FGL_J1323.9+1405 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0709.1+2241
# ============================================================
# ERROR processing 4FGL_J0709.1+2241 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1941.7+7218
# ============================================================
# ERROR processing 4FGL_J1941.7+7218 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0633.4-2222
# ============================================================
# ERROR processing 4FGL_J0633.4-2222 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0449.4-4350
# ============================================================
# ERROR processing 4FGL_J0449.4-4350 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1318.7-1234
# ============================================================
# ERROR processing 4FGL_J1318.7-1234 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2325.4-3559
# ============================================================
# ERROR processing 4FGL_J2325.4-3559 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1218.0-0028
# ============================================================
# ERROR processing 4FGL_J1218.0-0028 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1838.8+4802
# ============================================================
# ERROR processing 4FGL_J1838.8+4802 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0210.7-5101
# ============================================================
# ERROR processing 4FGL_J0210.7-5101 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0623.0-3010
# ============================================================
# ERROR processing 4FGL_J0623.0-3010 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1610.3-3958
# ============================================================
# ERROR processing 4FGL_J1610.3-3958 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0216.8-6635
# ============================================================
# ERROR processing 4FGL_J0216.8-6635 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0131.1+6120
# ============================================================
# ERROR processing 4FGL_J0131.1+6120 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0610.1-1848
# ============================================================
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# ERROR processing 4FGL_J0610.1-1848 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0009.3+5030
# ============================================================
# ERROR processing 4FGL_J0009.3+5030 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1949.5+0906
# ============================================================
# ERROR processing 4FGL_J1949.5+0906 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2056.2-4714
# ============================================================
# ERROR processing 4FGL_J2056.2-4714 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0753.9+0923
# ============================================================
# ERROR processing 4FGL_J0753.9+0923 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0502.5+1340
# ============================================================
# ERROR processing 4FGL_J0502.5+1340 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1848.5+3243
# ============================================================
# ERROR processing 4FGL_J1848.5+3243 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2221.5-5225
# ============================================================
# ERROR processing 4FGL_J2221.5-5225 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1345.6-3356
# ============================================================
# ERROR processing 4FGL_J1345.6-3356 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0315.9-1033
# ============================================================
# ERROR processing 4FGL_J0315.9-1033 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1129.1-5230
# ============================================================
# ERROR processing 4FGL_J1129.1-5230 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1330.2+7002
# ============================================================
# ERROR processing 4FGL_J1330.2+7002 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1717.5-3342
# ============================================================
# ERROR processing 4FGL_J1717.5-3342 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1632.8-1048
# ============================================================
# ERROR processing 4FGL_J1632.8-1048 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0222.6+4302
# ============================================================
# ERROR processing 4FGL_J0222.6+4302 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1329.0-5607
# ============================================================
# ERROR processing 4FGL_J1329.0-5607 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0033.9+3858
# ============================================================
# ERROR processing 4FGL_J0033.9+3858 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1722.6+6104
# ============================================================
# ERROR processing 4FGL_J1722.6+6104 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0134.3-3842
# ============================================================
# ERROR processing 4FGL_J0134.3-3842 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2026.0-2845
# ============================================================
# ERROR processing 4FGL_J2026.0-2845 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0746.5+2730
# ============================================================
# ERROR processing 4FGL_J0746.5+2730 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0416.5-1852
# ============================================================
# ERROR processing 4FGL_J0416.5-1852 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0539.6+1432
# ============================================================
# ERROR processing 4FGL_J0539.6+1432 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1829.2-5813
# ============================================================
# ERROR processing 4FGL_J1829.2-5813 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1733.0-1305
# ============================================================
# ERROR processing 4FGL_J1733.0-1305 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2001.5-0818
# ============================================================
# ERROR processing 4FGL_J2001.5-0818 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2012.2-1646
# ============================================================
# ERROR processing 4FGL_J2012.2-1646 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1550.7+0528
# ============================================================
# ERROR processing 4FGL_J1550.7+0528 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2216.9+2421
# ============================================================
# ERROR processing 4FGL_J2216.9+2421 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1131.4-0504
# ============================================================
# ERROR processing 4FGL_J1131.4-0504 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2005.5+7752
# ============================================================
# ERROR processing 4FGL_J2005.5+7752 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1208.4+6121
# ============================================================
# ERROR processing 4FGL_J1208.4+6121 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1649.4+5235
# ============================================================
# ERROR processing 4FGL_J1649.4+5235 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1150.6+4154
# ============================================================
# ERROR processing 4FGL_J1150.6+4154 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0532.0-4827
# ============================================================
# ERROR processing 4FGL_J0532.0-4827 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1059.5+2057
# ============================================================
# ERROR processing 4FGL_J1059.5+2057 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0019.6+7327
# ============================================================
# ERROR processing 4FGL_J0019.6+7327 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1548.3+1456
# ============================================================
# ERROR processing 4FGL_J1548.3+1456 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0533.0-8446
# ============================================================
# ERROR processing 4FGL_J0533.0-8446 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0747.3-3310
# ============================================================
# ERROR processing 4FGL_J0747.3-3310 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1011.3-0427
# ============================================================
# ERROR processing 4FGL_J1011.3-0427 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0258.1+2030
# ============================================================
# ERROR processing 4FGL_J0258.1+2030 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1248.9+4840
# ============================================================
# ERROR processing 4FGL_J1248.9+4840 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1910.8+2856
# ============================================================
# ERROR processing 4FGL_J1910.8+2856 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1129.5+3034
# ============================================================
# ERROR processing 4FGL_J1129.5+3034 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2325.4-4800
# ============================================================
# ERROR processing 4FGL_J2325.4-4800 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2243.8-2510
# ============================================================
# ERROR processing 4FGL_J2243.8-2510 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0228.3-5547
# ============================================================
# ERROR processing 4FGL_J0228.3-5547 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0304.5+3349
# ============================================================
# ERROR processing 4FGL_J0304.5+3349 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0347.0+4844
# ============================================================
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# ERROR processing 4FGL_J0347.0+4844 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0738.1+1742
# ============================================================
# ERROR processing 4FGL_J0738.1+1742 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0650.7+2503
# ============================================================
# ERROR processing 4FGL_J0650.7+2503 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1316.1-3338
# ============================================================
# ERROR processing 4FGL_J1316.1-3338 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1912.0+1612
# ============================================================
# ERROR processing 4FGL_J1912.0+1612 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2153.8-1137
# ============================================================
# ERROR processing 4FGL_J2153.8-1137 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1204.2-0709
# ============================================================
# ERROR processing 4FGL_J1204.2-0709 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0308.4+0407
# ============================================================
# ERROR processing 4FGL_J0308.4+0407 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1839.4-0553
# ============================================================
# ERROR processing 4FGL_J1839.4-0553 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2251.5-4928
# ============================================================
# ERROR processing 4FGL_J2251.5-4928 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2146.4-1528
# ============================================================
# ERROR processing 4FGL_J2146.4-1528 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0405.6-1308
# ============================================================
# ERROR processing 4FGL_J0405.6-1308 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1707.9+0016
# ...
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# ERROR processing 4FGL_J1955.4+5132 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J2320.8-0823
# ============================================================
# ERROR processing 4FGL_J2320.8-0823 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0805.4+6147
# ============================================================
# ERROR processing 4FGL_J0805.4+6147 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0225.6-4502
# ============================================================
# ERROR processing 4FGL_J0225.6-4502 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0238.1-2621
# ============================================================
# ERROR processing 4FGL_J0238.1-2621 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J1759.1-3849
# ============================================================
# ERROR processing 4FGL_J1759.1-3849 (flux): name 'predicted_val' is not defined
#
# ============================================================
# Running 4FGL_J0537.5+0959
# ============================================================
# ERROR processing 4FGL_J0537.5+0959 (flux): name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
# Traceback (most recent call last):
#   File "/var/folders/zs/0bs6mcrx3rd8fyhtblmctmx833tbwq/T/ipykernel_71634/1281297022.py", line 28, in <module>
#     f'{model_type}_predicted': predicted_val
# NameError: name 'predicted_val' is not defined
