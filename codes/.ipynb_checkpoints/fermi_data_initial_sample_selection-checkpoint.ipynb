# %%
import astropy
import numpy as np
import pandas
import os,sys

from astropy.io import fits

import os
import sys

from astropy.table import Table
from astropy.time import Time
import matplotlib.pylab as plt

import glob

import matplotlib as mpl
import scipy

import pyLCR
from astropy.io import fits
import pickle
import datetime

from codes_from_pylcr import *

font = {'size'   : 25}
mpl.rc('font', **font)
# Out:
# The Fermi-LAT Light Curve Repository Toolkit v0.1.0
# Support Contact: Daniel Kocevski (daniel.kocevski@nasa.gov)

# %%
wdir = f'/Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Main/Fermi_Sample/'
os.chdir(wdir)

# %%
cat_4fgl_dr4 = fits.open("4FGL_dr4.fit")
cat_4fgl_dr4_data = np.array(cat_4fgl_dr4[1].data)
del cat_4fgl_dr4

# %%
# Plot to see distribution of data in the 4FGL Catalog 

fig, ax = plt.subplots(1,1, figsize=(20,10))

ax.hist(cat_4fgl_dr4_data['CLASS1'],bins=40)
ax.tick_params(axis='x', labelrotation=90)
ax.set_yscale("log")
plt.title("Histogram of classes of Sources")
# Out:
# Text(0.5, 1.0, 'Histogram of classes of Sources')

# %%
# To get Column labels uncomment below:
#cat_4fgl_dr4_data.dtype

# %% [markdown]
# #### Add Fermi LC repo data
# Now Get the Fermi LC repo data and keep only sources that exist in both!
# For this study we dont divide into sub samples, as we are testing the population as a whole but each source with its past data.
# Later the ML code can be improved to add more parameters based on the subclass of the source to see if predictions can get better.

# %%
n_sources = len(cat_4fgl_dr4_data)
print("Total number of sources used ",n_sources)
# Out:
# Total number of sources used  7195

# %% [markdown]
# Note that: The LCR provides light curves for all sources in the 4FGL-DR2 catalog that exhibit a variability index greater than 21.67, where the variability index can be thought of as a proxy to the average fractional variability with dF/F measured on timescales of 1 year. As defined in the 4FGL-DR2 catalog, sources with a variability index greater than 21.67 over 12 intervals are estimated to have a < 1% chance of being a steady source. (From https://fermi.gsfc.nasa.gov/ssc/data/access/lat/LightCurveRepository/about.html)

# %% [markdown]
# ## Data Download:
# This can be skipped after the initial run

# %%
os.getcwd()
# Out:
# '/Users/aadesai1/Desktop/In_use/ML_work/Fermi_amego_alert_project/Main/Fermi_Sample'

# %%
skipped_sources=0
for indi_i in range(len(cat_4fgl_dr4_data)):
    name_tested = cat_4fgl_dr4_data[indi_i][0][:-1].decode('UTF-8')
    if os.path.isfile(f'../../data_fermi_LC_from_lc_repo/saved_lc_4FGL_{name_tested[-12:]}.pickle')==False:
        data_loaded = pyLCR.getLightCurve(name_tested, cadence='weekly', flux_type='photon', index_type='free', ts_min=4)
        try:
            loaded_arr = get_infor_from_fermi_lc(data_loaded)
        except:
            print(f'{name_tested} not found in LCR')
            skipped_sources+=1
            continue
        else:
            print(f'Found {name_tested}!')
        
    
        with open(f'../../data_fermi_LC_from_lc_repo/saved_lc_4FGL_{data_loaded.source[-12:]}.pickle', 'wb') as handle:
            pickle.dump(loaded_arr, handle, protocol=pickle.HIGHEST_PROTOCOL)
        print(f'{data_loaded.source[-12:]} printed on Pickle File')
    else:
        print(f'\n {name_tested[-12:]} existing')
print(f'Skipped {skipped_sources} sources out of {n_sources}')
# Out:
# Error: 4FGL J0000.3-7355 is not a source that is tracked by the LCR.
# 4FGL J0000.3-7355 not found in LCR
#
# Error: 4FGL J0000.5+0743 is not a source that is tracked by the LCR.
# 4FGL J0000.5+0743 not found in LCR
#
# Error: 4FGL J0000.7+2530 is not a source that is tracked by the LCR.
# 4FGL J0000.7+2530 not found in LCR
#
# Error: 4FGL J0001.2+4741 is not a source that is tracked by the LCR.
# 4FGL J0001.2+4741 not found in LCR
#
#  J0001.2-0747 existing
#
# Error: 4FGL J0001.4-0010 is not a source that is tracked by the LCR.
# 4FGL J0001.4-0010 not found in LCR
#
#  J0001.5+2113 existing
#
# Error: 4FGL J0001.6+3503 is not a source that is tracked by the LCR.
# 4FGL J0001.6+3503 not found in LCR
#
# Error: 4FGL J0001.6-4156 is not a source that is tracked by the LCR.
# 4FGL J0001.6-4156 not found in LCR
#
# Error: 4FGL J0001.8-2153 is not a source that is tracked by the LCR.
# 4FGL J0001.8-2153 not found in LCR
#
# Error: 4FGL J0002.1-6728 is not a source that is tracked by the LCR.
# 4FGL J0002.1-6728 not found in LCR
#
# Error: 4FGL J0002.1+6721 is not a source that is tracked by the LCR.
# 4FGL J0002.1+6721 not found in LCR
#
# Error: 4FGL J0002.3-0815 is not a source that is tracked by the LCR.
# 4FGL J0002.3-0815 not found in LCR
#
# Error: 4FGL J0002.4-5156 is not a source that is tracked by the LCR.
# 4FGL J0002.4-5156 not found in LCR
#
# Error: 4FGL J0002.7+7220 is not a source that is tracked by the LCR.
# 4FGL J0002.7+7220 not found in LCR
#
# Error: 4FGL J0002.8+6217 is not a source that is tracked by the LCR.
# 4FGL J0002.8+6217 not found in LCR
#
# Error: 4FGL J0003.1-5248 is not a source that is tracked by the LCR.
# 4FGL J0003.1-5248 not found in LCR
#
# Error: 4FGL J0003.1-1543 is not a source that is tracked by the LCR.
# 4FGL J0003.1-1543 not found in LCR
#
# Error: 4FGL J0003.2+2207 is not a source that is tracked by the LCR.
# 4FGL J0003.2+2207 not found in LCR
#
# Error: 4FGL J0003.3-0703 is not a source that is tracked by the LCR.
# 4FGL J0003.3-0703 not found in LCR
#
# Error: 4FGL J0003.3+2511 is not a source that is tracked by the LCR.
# 4FGL J0003.3+2511 not found in LCR
#
#  J0003.3-1928 existing
#
# Error: 4FGL J0003.3-5905 is not a source that is tracked by the LCR.
# 4FGL J0003.3-5905 not found in LCR
#
# Error: 4FGL J0003.5+0717 is not a source that is tracked by the LCR.
# 4FGL J0003.5+0717 not found in LCR
#
# Error: 4FGL J0003.6+3059 is not a source that is tracked by the LCR.
# 4FGL J0003.6+3059 not found in LCR
#
# Error: 4FGL J0003.9-1149 is not a source that is tracked by the LCR.
# 4FGL J0003.9-1149 not found in LCR
#
# Error: 4FGL J0004.0+5715 is not a source that is tracked by the LCR.
# 4FGL J0004.0+5715 not found in LCR
#
# Error: 4FGL J0004.0+0840 is not a source that is tracked by the LCR.
# 4FGL J0004.0+0840 not found in LCR
#
#  J0004.3+4614 existing
#
#  J0004.4-4737 existing
#
#  J0004.4-4001 existing
#
# Error: 4FGL J0005.5+6634 is not a source that is tracked by the LCR.
# 4FGL J0005.5+6634 not found in LCR
#
# Error: 4FGL J0005.6+6746 is not a source that is tracked by the LCR.
# 4FGL J0005.6+6746 not found in LCR
#
#  J0005.9+3824 existing
#
# Error: 4FGL J0006.3-1813 is not a source that is tracked by the LCR.
# 4FGL J0006.3-1813 not found in LCR
#
# Error: 4FGL J0006.3-0620 is not a source that is tracked by the LCR.
# 4FGL J0006.3-0620 not found in LCR
#
# Error: 4FGL J0006.4+0135 is not a source that is tracked by the LCR.
# 4FGL J0006.4+0135 not found in LCR
#
# Error: 4FGL J0006.4-5621 is not a source that is tracked by the LCR.
# 4FGL J0006.4-5621 not found in LCR
#
# Error: 4FGL J0006.6+4618 is not a source that is tracked by the LCR.
# 4FGL J0006.6+4618 not found in LCR
#
# Error: 4FGL J0007.0+7303 is not a source that is tracked by the LCR.
# 4FGL J0007.0+7303 not found in LCR
#
# Error: 4FGL J0007.4-0322 is not a source that is tracked by the LCR.
# 4FGL J0007.4-0322 not found in LCR
#
# Error: 4FGL J0007.5-5247 is not a source that is tracked by the LCR.
# 4FGL J0007.5-5247 not found in LCR
#
#  J0007.7+4008 existing
#
# Error: 4FGL J0008.0+4711 is not a source that is tracked by the LCR.
# 4FGL J0008.0+4711 not found in LCR
#
# Error: 4FGL J0008.0-3937 is not a source that is tracked by the LCR.
# 4FGL J0008.0-3937 not found in LCR
#
# Error: 4FGL J0008.4+6926 is not a source that is tracked by the LCR.
# 4FGL J0008.4+6926 not found in LCR
#
# Error: 4FGL J0008.4-2339 is not a source that is tracked by the LCR.
# 4FGL J0008.4-2339 not found in LCR
#
# Error: 4FGL J0008.4+6837 is not a source that is tracked by the LCR.
# 4FGL J0008.4+6837 not found in LCR
#
# Error: 4FGL J0008.4+1455 is not a source that is tracked by the LCR.
# 4FGL J0008.4+1455 not found in LCR
#
# Error: 4FGL J0008.9+2509 is not a source that is tracked by the LCR.
# 4FGL J0008.9+2509 not found in LCR
#
#  J0009.1-5012 existing
#
# Error: 4FGL J0009.1+0628 is not a source that is tracked by the LCR.
# 4FGL J0009.1+0628 not found in LCR
#
# Error: 4FGL J0009.2+1745 is not a source that is tracked by the LCR.
# 4FGL J0009.2+1745 not found in LCR
#
#  J0009.3+5030 existing
#
# Error: 4FGL J0009.7-1418 is not a source that is tracked by the LCR.
# 4FGL J0009.7-1418 not found in LCR
#
# Error: 4FGL J0009.7-3217 is not a source that is tracked by the LCR.
# 4FGL J0009.7-3217 not found in LCR
#
# Error: 4FGL J0009.8-4317 is not a source that is tracked by the LCR.
# 4FGL J0009.8-4317 not found in LCR
#
# Error: 4FGL J0009.8+1340 is not a source that is tracked by the LCR.
# 4FGL J0009.8+1340 not found in LCR
#
# Error: 4FGL J0009.8-6358 is not a source that is tracked by the LCR.
# 4FGL J0009.8-6358 not found in LCR
#
# Error: 4FGL J0009.9+2810 is not a source that is tracked by the LCR.
# 4FGL J0009.9+2810 not found in LCR
#
# Error: 4FGL J0010.1+1631 is not a source that is tracked by the LCR.
# 4FGL J0010.1+1631 not found in LCR
#
# Error: 4FGL J0010.2-2431 is not a source that is tracked by the LCR.
# 4FGL J0010.2-2431 not found in LCR
#
#  J0010.6+2043 existing
#
#  J0010.6-3025 existing
#
# Error: 4FGL J0010.8-2154 is not a source that is tracked by the LCR.
# 4FGL J0010.8-2154 not found in LCR
#
# Error: 4FGL J0011.4-4110 is not a source that is tracked by the LCR.
# 4FGL J0011.4-4110 not found in LCR
#
#  J0011.4+0057 existing
#
# Error: 4FGL J0011.5+4822 is not a source that is tracked by the LCR.
# 4FGL J0011.5+4822 not found in LCR
#
# Error: 4FGL J0011.8-3142 is not a source that is tracked by the LCR.
# 4FGL J0011.8-3142 not found in LCR
#
# Error: 4FGL J0012.0+7043 is not a source that is tracked by the LCR.
# 4FGL J0012.0+7043 not found in LCR
#
# Error: 4FGL J0013.0+3355 is not a source that is tracked by the LCR.
# 4FGL J0013.0+3355 not found in LCR
#
# Error: 4FGL J0013.1-3955 is not a source that is tracked by the LCR.
# 4FGL J0013.1-3955 not found in LCR
#
# Error: 4FGL J0013.4+0950 is not a source that is tracked by the LCR.
# 4FGL J0013.4+0950 not found in LCR
#
# Error: 4FGL J0013.6+4051 is not a source that is tracked by the LCR.
# 4FGL J0013.6+4051 not found in LCR
#
# Error: 4FGL J0013.6-0424 is not a source that is tracked by the LCR.
# 4FGL J0013.6-0424 not found in LCR
#
# Error: 4FGL J0013.9-1854 is not a source that is tracked by the LCR.
# 4FGL J0013.9-1854 not found in LCR
#
#  J0014.1+1910 existing
#
# Error: 4FGL J0014.1-5022 is not a source that is tracked by the LCR.
# 4FGL J0014.1-5022 not found in LCR
#
# Error: 4FGL J0014.2+0854 is not a source that is tracked by the LCR.
# 4FGL J0014.2+0854 not found in LCR
#
#  J0014.3-0500 existing
#
# Error: 4FGL J0014.7+5801 is not a source that is tracked by the LCR.
# 4FGL J0014.7+5801 not found in LCR
#
# Error: 4FGL J0014.8+6118 is not a source that is tracked by the LCR.
# 4FGL J0014.8+6118 not found in LCR
#
#  J0014.9+3212 existing
#
# Error: 4FGL J0015.2+3537 is not a source that is tracked by the LCR.
# 4FGL J0015.2+3537 not found in LCR
#
# Error: 4FGL J0015.6+5551 is not a source that is tracked by the LCR.
# 4FGL J0015.6+5551 not found in LCR
#
# Error: 4FGL J0015.9+2440 is not a source that is tracked by the LCR.
# 4FGL J0015.9+2440 not found in LCR
#
#  J0016.2-0016 existing
#
# Error: 4FGL J0016.5+1702 is not a source that is tracked by the LCR.
# 4FGL J0016.5+1702 not found in LCR
#
#  J0017.0-0649 existing
#
# Error: 4FGL J0017.1-4605 is not a source that is tracked by the LCR.
# 4FGL J0017.1-4605 not found in LCR
#
# Error: 4FGL J0017.4+6506 is not a source that is tracked by the LCR.
# 4FGL J0017.4+6506 not found in LCR
#
#  J0017.5-0514 existing
#
# Error: 4FGL J0017.8+1455 is not a source that is tracked by the LCR.
# 4FGL J0017.8+1455 not found in LCR
#
# Error: 4FGL J0018.4+2946 is not a source that is tracked by the LCR.
# 4FGL J0018.4+2946 not found in LCR
#
# Error: 4FGL J0018.8+5112 is not a source that is tracked by the LCR.
# 4FGL J0018.8+5112 not found in LCR
#
# Error: 4FGL J0018.8+2611 is not a source that is tracked by the LCR.
# 4FGL J0018.8+2611 not found in LCR
#
#  J0019.2-5640 existing
#
# Error: 4FGL J0019.3-8152 is not a source that is tracked by the LCR.
# 4FGL J0019.3-8152 not found in LCR
#
#  J0019.6+7327 existing
#
# Error: 4FGL J0019.6+2022 is not a source that is tracked by the LCR.
# 4FGL J0019.6+2022 not found in LCR
#
# Error: 4FGL J0020.3+6919 is not a source that is tracked by the LCR.
# 4FGL J0020.3+6919 not found in LCR
#
# Error: 4FGL J0021.0+0322 is not a source that is tracked by the LCR.
# 4FGL J0021.0+0322 not found in LCR
#
# Error: 4FGL J0021.5-2221 is not a source that is tracked by the LCR.
# 4FGL J0021.5-2221 not found in LCR
#
#  J0021.5-2552 existing
#
# Error: 4FGL J0021.6-0855 is not a source that is tracked by the LCR.
# 4FGL J0021.6-0855 not found in LCR
#
# Error: 4FGL J0021.7+4533 is not a source that is tracked by the LCR.
# 4FGL J0021.7+4533 not found in LCR
#
#  J0021.9-5140 existing
#
# Error: 4FGL J0022.0+0006 is not a source that is tracked by the LCR.
# 4FGL J0022.0+0006 not found in LCR
#
# Error: 4FGL J0022.0-5921 is not a source that is tracked by the LCR.
# 4FGL J0022.0-5921 not found in LCR
#
# Error: 4FGL J0022.1-1854 is not a source that is tracked by the LCR.
# 4FGL J0022.1-1854 not found in LCR
#
#  J0022.5+0608 existing
#
# Error: 4FGL J0023.2+8412 is not a source that is tracked by the LCR.
# 4FGL J0023.2+8412 not found in LCR
#
# Error: 4FGL J0023.4+0920 is not a source that is tracked by the LCR.
# 4FGL J0023.4+0920 not found in LCR
#
# Error: 4FGL J0023.6-4209 is not a source that is tracked by the LCR.
# 4FGL J0023.6-4209 not found in LCR
#
#  J0023.7-6820 existing
#
#  J0023.7+4457 existing
#
# Error: 4FGL J0023.9+1603 is not a source that is tracked by the LCR.
# 4FGL J0023.9+1603 not found in LCR
#
# Error: 4FGL J0024.0-7204 is not a source that is tracked by the LCR.
# 4FGL J0024.0-7204 not found in LCR
#
# Error: 4FGL J0024.1+2402 is not a source that is tracked by the LCR.
# 4FGL J0024.1+2402 not found in LCR
#
# Error: 4FGL J0024.1+7909 is not a source that is tracked by the LCR.
# 4FGL J0024.1+7909 not found in LCR
#
#  J0024.4+4647 existing
#
# Error: 4FGL J0024.5-0810 is not a source that is tracked by the LCR.
# 4FGL J0024.5-0810 not found in LCR
#
#  J0024.7+0349 existing
#
# Error: 4FGL J0025.0-2320 is not a source that is tracked by the LCR.
# 4FGL J0025.0-2320 not found in LCR
#
# Error: 4FGL J0025.2-2231 is not a source that is tracked by the LCR.
# 4FGL J0025.2-2231 not found in LCR
#
# Error: 4FGL J0025.3+6408 is not a source that is tracked by the LCR.
# 4FGL J0025.3+6408 not found in LCR
#
# Error: 4FGL J0025.4-4838 is not a source that is tracked by the LCR.
# 4FGL J0025.4-4838 not found in LCR
#
# Error: 4FGL J0025.5-5936 is not a source that is tracked by the LCR.
# 4FGL J0025.5-5936 not found in LCR
#
#  J0025.7-4801 existing
#
# Error: 4FGL J0026.1-0732 is not a source that is tracked by the LCR.
# 4FGL J0026.1-0732 not found in LCR
#
# Error: 4FGL J0026.2+3926 is not a source that is tracked by the LCR.
# 4FGL J0026.2+3926 not found in LCR
#
# Error: 4FGL J0026.6-4600 is not a source that is tracked by the LCR.
# 4FGL J0026.6-4600 not found in LCR
#
# Error: 4FGL J0027.0-1134 is not a source that is tracked by the LCR.
# 4FGL J0027.0-1134 not found in LCR
#
# Error: 4FGL J0028.1+7505 is not a source that is tracked by the LCR.
# 4FGL J0028.1+7505 not found in LCR
#
# Error: 4FGL J0028.5+2001 is not a source that is tracked by the LCR.
# 4FGL J0028.5+2001 not found in LCR
#
# Error: 4FGL J0028.8-0112 is not a source that is tracked by the LCR.
# 4FGL J0028.8-0112 not found in LCR
#
# Error: 4FGL J0028.9+3553 is not a source that is tracked by the LCR.
# 4FGL J0028.9+3553 not found in LCR
#
#  J0029.0-7044 existing
#
# Error: 4FGL J0029.4+2051 is not a source that is tracked by the LCR.
# 4FGL J0029.4+2051 not found in LCR
#
# Error: 4FGL J0030.2+0001 is not a source that is tracked by the LCR.
# 4FGL J0030.2+0001 not found in LCR
#
# Error: 4FGL J0030.2-5149 is not a source that is tracked by the LCR.
# 4FGL J0030.2-5149 not found in LCR
#
#  J0030.2-1647 existing
#
#  J0030.3-4224 existing
#
# Error: 4FGL J0030.4+0451 is not a source that is tracked by the LCR.
# 4FGL J0030.4+0451 not found in LCR
#
#  J0030.6-0212 existing
#
# Error: 4FGL J0030.6+0539 is not a source that is tracked by the LCR.
# 4FGL J0030.6+0539 not found in LCR
#
# Error: 4FGL J0030.9-3618 is not a source that is tracked by the LCR.
# 4FGL J0030.9-3618 not found in LCR
#
# Error: 4FGL J0031.0-2327 is not a source that is tracked by the LCR.
# 4FGL J0031.0-2327 not found in LCR
#
# Error: 4FGL J0031.3+0726 is not a source that is tracked by the LCR.
# 4FGL J0031.3+0726 not found in LCR
#
# Error: 4FGL J0031.5-4025 is not a source that is tracked by the LCR.
# 4FGL J0031.5-4025 not found in LCR
#
# Error: 4FGL J0031.5-5648 is not a source that is tracked by the LCR.
# 4FGL J0031.5-5648 not found in LCR
#
#  J0032.3-5522 existing
#
# Error: 4FGL J0032.3-5539 is not a source that is tracked by the LCR.
# 4FGL J0032.3-5539 not found in LCR
#
# Error: 4FGL J0032.4-2849 is not a source that is tracked by the LCR.
# 4FGL J0032.4-2849 not found in LCR
#
# Error: 4FGL J0032.5-4724 is not a source that is tracked by the LCR.
# 4FGL J0032.5-4724 not found in LCR
#
# Error: 4FGL J0033.3-2040 is not a source that is tracked by the LCR.
# 4FGL J0033.3-2040 not found in LCR
#
#  J0033.5-1921 existing
#
#  J0033.9+3858 existing
#
#  J0034.0-4116 existing
#
# Error: 4FGL J0034.3-0534 is not a source that is tracked by the LCR.
# 4FGL J0034.3-0534 not found in LCR
#
# Error: 4FGL J0034.6+6438 is not a source that is tracked by the LCR.
# 4FGL J0034.6+6438 not found in LCR
#
# Error: 4FGL J0035.0-5728 is not a source that is tracked by the LCR.
# 4FGL J0035.0-5728 not found in LCR
#
#  J0035.2+1514 existing
#
# Error: 4FGL J0035.2-1739 is not a source that is tracked by the LCR.
# 4FGL J0035.2-1739 not found in LCR
#
# Error: 4FGL J0035.8-0837 is not a source that is tracked by the LCR.
# 4FGL J0035.8-0837 not found in LCR
#
#  J0035.8+6131 existing
#
#  J0035.9+5950 existing
#
# Error: 4FGL J0036.8+1431 is not a source that is tracked by the LCR.
# 4FGL J0036.8+1431 not found in LCR
#
#  J0036.9+1832 existing
#
# Error: 4FGL J0037.2-2653 is not a source that is tracked by the LCR.
# 4FGL J0037.2-2653 not found in LCR
#
# Error: 4FGL J0037.6+3653 is not a source that is tracked by the LCR.
# 4FGL J0037.6+3653 not found in LCR
#
#  J0037.8+1239 existing
#
# Error: 4FGL J0037.9+2612 is not a source that is tracked by the LCR.
# 4FGL J0037.9+2612 not found in LCR
#
# Error: 4FGL J0038.1+0012 is not a source that is tracked by the LCR.
# 4FGL J0038.1+0012 not found in LCR
#
#  J0038.2-2459 existing
#
# Error: 4FGL J0038.7-0204 is not a source that is tracked by the LCR.
# 4FGL J0038.7-0204 not found in LCR
#
# Error: 4FGL J0039.0-0946 is not a source that is tracked by the LCR.
# 4FGL J0039.0-0946 not found in LCR
#
# Error: 4FGL J0039.1-2219 is not a source that is tracked by the LCR.
# 4FGL J0039.1-2219 not found in LCR
#
# Error: 4FGL J0039.1+6257 is not a source that is tracked by the LCR.
# 4FGL J0039.1+6257 not found in LCR
#
#  J0039.1+4330 existing
#
# Error: 4FGL J0039.7+4203 is not a source that is tracked by the LCR.
# 4FGL J0039.7+4203 not found in LCR
#
# Error: 4FGL J0040.2-2725 is not a source that is tracked by the LCR.
# 4FGL J0040.2-2725 not found in LCR
#
# Error: 4FGL J0040.3+4050 is not a source that is tracked by the LCR.
# 4FGL J0040.3+4050 not found in LCR
#
# Error: 4FGL J0040.4-2340 is not a source that is tracked by the LCR.
# 4FGL J0040.4-2340 not found in LCR
#
# Error: 4FGL J0040.7-7157 is not a source that is tracked by the LCR.
# 4FGL J0040.7-7157 not found in LCR
#
# Error: 4FGL J0040.9+3203 is not a source that is tracked by the LCR.
# 4FGL J0040.9+3203 not found in LCR
#
# Error: 4FGL J0041.3-0048 is not a source that is tracked by the LCR.
# 4FGL J0041.3-0048 not found in LCR
#
# Error: 4FGL J0041.3+6052 is not a source that is tracked by the LCR.
# 4FGL J0041.3+6052 not found in LCR
#
# Error: 4FGL J0041.4+3800 is not a source that is tracked by the LCR.
# 4FGL J0041.4+3800 not found in LCR
#
# Error: 4FGL J0041.7-1607 is not a source that is tracked by the LCR.
# 4FGL J0041.7-1607 not found in LCR
#
# Error: 4FGL J0041.9-4702 is not a source that is tracked by the LCR.
# 4FGL J0041.9-4702 not found in LCR
#
# Error: 4FGL J0042.0+3640 is not a source that is tracked by the LCR.
# 4FGL J0042.0+3640 not found in LCR
#
# Error: 4FGL J0042.2+2319 is not a source that is tracked by the LCR.
# 4FGL J0042.2+2319 not found in LCR
#
# Error: 4FGL J0042.3+3509 is not a source that is tracked by the LCR.
# 4FGL J0042.3+3509 not found in LCR
#
# Error: 4FGL J0043.2+4114 is not a source that is tracked by the LCR.
# 4FGL J0043.2+4114 not found in LCR
#
# Error: 4FGL J0043.5-0442 is not a source that is tracked by the LCR.
# 4FGL J0043.5-0442 not found in LCR
#
# Error: 4FGL J0043.6+2223 is not a source that is tracked by the LCR.
# 4FGL J0043.6+2223 not found in LCR
#
# Error: 4FGL J0043.7-1116 is not a source that is tracked by the LCR.
# 4FGL J0043.7-1116 not found in LCR
#
#  J0043.8+3425 existing
#
#  J0044.2-8424 existing
#
# Error: 4FGL J0044.8+6802 is not a source that is tracked by the LCR.
# 4FGL J0044.8+6802 not found in LCR
#
# Error: 4FGL J0044.9+4553 is not a source that is tracked by the LCR.
# 4FGL J0044.9+4553 not found in LCR
#
#  J0045.1-3706 existing
#
#  J0045.3+2128 existing
#
#  J0045.7+1217 existing
#
# Error: 4FGL J0045.8-1324 is not a source that is tracked by the LCR.
# 4FGL J0045.8-1324 not found in LCR
#
# Error: 4FGL J0045.9-2021 is not a source that is tracked by the LCR.
# 4FGL J0045.9-2021 not found in LCR
#
# Error: 4FGL J0046.7-7048 is not a source that is tracked by the LCR.
# 4FGL J0046.7-7048 not found in LCR
#
# Error: 4FGL J0046.9+0705 is not a source that is tracked by the LCR.
# 4FGL J0046.9+0705 not found in LCR
#
#  J0047.0+5657 existing
#
# Error: 4FGL J0047.1-6203 is not a source that is tracked by the LCR.
# 4FGL J0047.1-6203 not found in LCR
#
# Error: 4FGL J0047.3+6943 is not a source that is tracked by the LCR.
# 4FGL J0047.3+6943 not found in LCR
#
# Error: 4FGL J0047.5-2517 is not a source that is tracked by the LCR.
# 4FGL J0047.5-2517 not found in LCR
#
#  J0047.9+3947 existing
#
# Error: 4FGL J0047.9+5448 is not a source that is tracked by the LCR.
# 4FGL J0047.9+5448 not found in LCR
#
#  J0047.9+2233 existing
#
# Error: 4FGL J0048.6-6347 is not a source that is tracked by the LCR.
# 4FGL J0048.6-6347 not found in LCR
#
# Error: 4FGL J0048.6-2427 is not a source that is tracked by the LCR.
# 4FGL J0048.6-2427 not found in LCR
#
# Error: 4FGL J0049.0+2252 is not a source that is tracked by the LCR.
# 4FGL J0049.0+2252 not found in LCR
#
# Error: 4FGL J0049.1+4223 is not a source that is tracked by the LCR.
# 4FGL J0049.1+4223 not found in LCR
#
# Error: 4FGL J0049.2+6227 is not a source that is tracked by the LCR.
# 4FGL J0049.2+6227 not found in LCR
#
# Error: 4FGL J0049.4-5402 is not a source that is tracked by the LCR.
# 4FGL J0049.4-5402 not found in LCR
#
# Error: 4FGL J0049.5-4150 is not a source that is tracked by the LCR.
# 4FGL J0049.5-4150 not found in LCR
#
# Error: 4FGL J0049.6-4500 is not a source that is tracked by the LCR.
# 4FGL J0049.6-4500 not found in LCR
#
#  J0049.7+0237 existing
#
#  J0050.0-5736 existing
#
#  J0050.4-0452 existing
#
#  J0050.7-0929 existing
#
# Error: 4FGL J0050.8+3330 is not a source that is tracked by the LCR.
# 4FGL J0050.8+3330 not found in LCR
#
# Error: 4FGL J0050.8-3428 is not a source that is tracked by the LCR.
# 4FGL J0050.8-3428 not found in LCR
#
#  J0051.1-0648 existing
#
#  J0051.2-6242 existing
#
#  J0051.5-4220 existing
#
# Error: 4FGL J0052.1+6444 is not a source that is tracked by the LCR.
# 4FGL J0052.1+6444 not found in LCR
#
# Error: 4FGL J0052.9-6644 is not a source that is tracked by the LCR.
# 4FGL J0052.9-6644 not found in LCR
#
# Error: 4FGL J0054.4+8627 is not a source that is tracked by the LCR.
# 4FGL J0054.4+8627 not found in LCR
#
# Error: 4FGL J0054.4-1503 is not a source that is tracked by the LCR.
# 4FGL J0054.4-1503 not found in LCR
#
# Error: 4FGL J0054.7-2455 is not a source that is tracked by the LCR.
# 4FGL J0054.7-2455 not found in LCR
#
# Error: 4FGL J0054.8-1954 is not a source that is tracked by the LCR.
# 4FGL J0054.8-1954 not found in LCR
#
#  J0055.1-1219 existing
#
# Error: 4FGL J0055.7+4507 is not a source that is tracked by the LCR.
# 4FGL J0055.7+4507 not found in LCR
#
#  J0056.3-0935 existing
#
#  J0056.4-2118 existing
#
# Error: 4FGL J0056.5-3936 is not a source that is tracked by the LCR.
# 4FGL J0056.5-3936 not found in LCR
#
# Error: 4FGL J0056.6-4452 is not a source that is tracked by the LCR.
# 4FGL J0056.6-4452 not found in LCR
#
#  J0056.6-5317 existing
#
# Error: 4FGL J0056.8+1626 is not a source that is tracked by the LCR.
# 4FGL J0056.8+1626 not found in LCR
#
# Error: 4FGL J0057.0+4101 is not a source that is tracked by the LCR.
# 4FGL J0057.0+4101 not found in LCR
#
# Error: 4FGL J0057.3+2216 is not a source that is tracked by the LCR.
# 4FGL J0057.3+2216 not found in LCR
#
# Error: 4FGL J0057.5+6814 is not a source that is tracked by the LCR.
# 4FGL J0057.5+6814 not found in LCR
#
# Error: 4FGL J0057.7+3023 is not a source that is tracked by the LCR.
# 4FGL J0057.7+3023 not found in LCR
#
# Error: 4FGL J0057.9+6326 is not a source that is tracked by the LCR.
# 4FGL J0057.9+6326 not found in LCR
#
# Error: 4FGL J0058.0-7245 is not a source that is tracked by the LCR.
# 4FGL J0058.0-7245 not found in LCR
#
#  J0058.0-0539 existing
#
#  J0058.0-3233 existing
#
# Error: 4FGL J0058.1+6915 is not a source that is tracked by the LCR.
# 4FGL J0058.1+6915 not found in LCR
#
# Error: 4FGL J0058.3+1723 is not a source that is tracked by the LCR.
# 4FGL J0058.3+1723 not found in LCR
#
# Error: 4FGL J0058.3-4603 is not a source that is tracked by the LCR.
# 4FGL J0058.3-4603 not found in LCR
#
#  J0058.4+3315 existing
#
# Error: 4FGL J0058.6-1140 is not a source that is tracked by the LCR.
# 4FGL J0058.6-1140 not found in LCR
#
# Error: 4FGL J0059.2+0006 is not a source that is tracked by the LCR.
# 4FGL J0059.2+0006 not found in LCR
#
# Error: 4FGL J0059.3-0152 is not a source that is tracked by the LCR.
# 4FGL J0059.3-0152 not found in LCR
#
#  J0059.4-5654 existing
#
# Error: 4FGL J0059.5-3512 is not a source that is tracked by the LCR.
# 4FGL J0059.5-3512 not found in LCR
#
# Error: 4FGL J0059.5-3338 is not a source that is tracked by the LCR.
# 4FGL J0059.5-3338 not found in LCR
#
# Error: 4FGL J0059.7-7210 is not a source that is tracked by the LCR.
# 4FGL J0059.7-7210 not found in LCR
#
#  J0100.3+0745 existing
#
# Error: 4FGL J0101.0-0059 is not a source that is tracked by the LCR.
# 4FGL J0101.0-0059 not found in LCR
#
# Error: 4FGL J0101.1-6422 is not a source that is tracked by the LCR.
# 4FGL J0101.1-6422 not found in LCR
#
# Error: 4FGL J0101.3-8019 is not a source that is tracked by the LCR.
# 4FGL J0101.3-8019 not found in LCR
#
# Error: 4FGL J0101.7-5455 is not a source that is tracked by the LCR.
# 4FGL J0101.7-5455 not found in LCR
#
# Error: 4FGL J0101.8-7543 is not a source that is tracked by the LCR.
# 4FGL J0101.8-7543 not found in LCR
#
# Error: 4FGL J0102.0-6240 is not a source that is tracked by the LCR.
# 4FGL J0102.0-6240 not found in LCR
#
# Error: 4FGL J0102.0+1639 is not a source that is tracked by the LCR.
# 4FGL J0102.0+1639 not found in LCR
#
# Error: 4FGL J0102.1+5846 is not a source that is tracked by the LCR.
# 4FGL J0102.1+5846 not found in LCR
#
# Error: 4FGL J0102.1+4458 is not a source that is tracked by the LCR.
# 4FGL J0102.1+4458 not found in LCR
#
# Error: 4FGL J0102.3+1000 is not a source that is tracked by the LCR.
# 4FGL J0102.3+1000 not found in LCR
#
#  J0102.4+4214 existing
#
# Error: 4FGL J0102.4+0942 is not a source that is tracked by the LCR.
# 4FGL J0102.4+0942 not found in LCR
#
# Error: 4FGL J0102.6-5639 is not a source that is tracked by the LCR.
# 4FGL J0102.6-5639 not found in LCR
#
# Error: 4FGL J0102.7-2001 is not a source that is tracked by the LCR.
# 4FGL J0102.7-2001 not found in LCR
#
#  J0102.8+5824 existing
#
# Error: 4FGL J0102.8+4839 is not a source that is tracked by the LCR.
# 4FGL J0102.8+4839 not found in LCR
#
# Error: 4FGL J0102.9-7051 is not a source that is tracked by the LCR.
# 4FGL J0102.9-7051 not found in LCR
#
# Error: 4FGL J0103.1+4954 is not a source that is tracked by the LCR.
# 4FGL J0103.1+4954 not found in LCR
#
# Error: 4FGL J0103.5+1526 is not a source that is tracked by the LCR.
# 4FGL J0103.5+1526 not found in LCR
#
#  J0103.5+5337 existing
#
#  J0103.8+1321 existing
#
# Error: 4FGL J0104.6-0818 is not a source that is tracked by the LCR.
# 4FGL J0104.6-0818 not found in LCR
#
# Error: 4FGL J0104.8-2215 is not a source that is tracked by the LCR.
# 4FGL J0104.8-2215 not found in LCR
#
#  J0104.8-2416 existing
#
#  J0105.1+3929 existing
#
# Error: 4FGL J0105.5+1912 is not a source that is tracked by the LCR.
# 4FGL J0105.5+1912 not found in LCR
#
# Error: 4FGL J0105.9+3403 is not a source that is tracked by the LCR.
# 4FGL J0105.9+3403 not found in LCR
#
# Error: 4FGL J0106.1+1131 is not a source that is tracked by the LCR.
# 4FGL J0106.1+1131 not found in LCR
#
# Error: 4FGL J0106.4+4855 is not a source that is tracked by the LCR.
# 4FGL J0106.4+4855 not found in LCR
#
# Error: 4FGL J0106.9-4832 is not a source that is tracked by the LCR.
# 4FGL J0106.9-4832 not found in LCR
#
# Error: 4FGL J0107.3-1210 is not a source that is tracked by the LCR.
# 4FGL J0107.3-1210 not found in LCR
#
#  J0107.4+0334 existing
#
# Error: 4FGL J0107.4+0459 is not a source that is tracked by the LCR.
# 4FGL J0107.4+0459 not found in LCR
#
# Error: 4FGL J0107.6+4950 is not a source that is tracked by the LCR.
# 4FGL J0107.6+4950 not found in LCR
#
# Error: 4FGL J0108.1-0039 is not a source that is tracked by the LCR.
# 4FGL J0108.1-0039 not found in LCR
#
#  J0108.6+0134 existing
#
# Error: 4FGL J0109.1+1815 is not a source that is tracked by the LCR.
# 4FGL J0109.1+1815 not found in LCR
#
# Error: 4FGL J0109.3+2401 is not a source that is tracked by the LCR.
# 4FGL J0109.3+2401 not found in LCR
#
#  J0109.7+6133 existing
#
# Error: 4FGL J0110.0-5246 is not a source that is tracked by the LCR.
# 4FGL J0110.0-5246 not found in LCR
#
# Error: 4FGL J0110.0-4019 is not a source that is tracked by the LCR.
# 4FGL J0110.0-4019 not found in LCR
#
# Error: 4FGL J0110.1+6805 is not a source that is tracked by the LCR.
# 4FGL J0110.1+6805 not found in LCR
#
# Error: 4FGL J0110.2+4151 is not a source that is tracked by the LCR.
# 4FGL J0110.2+4151 not found in LCR
#
# Error: 4FGL J0110.3-0431 is not a source that is tracked by the LCR.
# 4FGL J0110.3-0431 not found in LCR
#
# Error: 4FGL J0110.6+0415 is not a source that is tracked by the LCR.
# 4FGL J0110.6+0415 not found in LCR
#
# Error: 4FGL J0110.7-1254 is not a source that is tracked by the LCR.
# 4FGL J0110.7-1254 not found in LCR
#
# Error: 4FGL J0110.9+4344 is not a source that is tracked by the LCR.
# 4FGL J0110.9+4344 not found in LCR
#
# Error: 4FGL J0111.4-7304 is not a source that is tracked by the LCR.
# 4FGL J0111.4-7304 not found in LCR
#
# Error: 4FGL J0111.4+0534 is not a source that is tracked by the LCR.
# 4FGL J0111.4+0534 not found in LCR
#
#  J0111.5-2546 existing
#
# Error: 4FGL J0112.0+3442 is not a source that is tracked by the LCR.
# 4FGL J0112.0+3442 not found in LCR
#
#  J0112.0-6634 existing
#
#  J0112.1+2245 existing
#
# Error: 4FGL J0112.1-0321 is not a source that is tracked by the LCR.
# 4FGL J0112.1-0321 not found in LCR
#
# Error: 4FGL J0112.5-0651 is not a source that is tracked by the LCR.
# 4FGL J0112.5-0651 not found in LCR
#
# Error: 4FGL J0112.6-3158 is not a source that is tracked by the LCR.
# 4FGL J0112.6-3158 not found in LCR
#
# Error: 4FGL J0112.8-7506 is not a source that is tracked by the LCR.
# 4FGL J0112.8-7506 not found in LCR
#
# Error: 4FGL J0112.8-0253 is not a source that is tracked by the LCR.
# 4FGL J0112.8-0253 not found in LCR
#
#  J0112.8+3208 existing
#
#  J0113.1-3553 existing
#
#  J0113.4+4948 existing
#
# Error: 4FGL J0113.7+0225 is not a source that is tracked by the LCR.
# 4FGL J0113.7+0225 not found in LCR
#
#  J0114.0+6418 existing
#
#  J0114.8+1326 existing
#
# Error: 4FGL J0114.9-3400 is not a source that is tracked by the LCR.
# 4FGL J0114.9-3400 not found in LCR
#
#  J0115.1+2622 existing
#
#  J0115.1-0129 existing
#
# Error: 4FGL J0115.4-2917 is not a source that is tracked by the LCR.
# 4FGL J0115.4-2917 not found in LCR
#
# Error: 4FGL J0115.6-5653 is not a source that is tracked by the LCR.
# 4FGL J0115.6-5653 not found in LCR
#
# Error: 4FGL J0115.6+0356 is not a source that is tracked by the LCR.
# 4FGL J0115.6+0356 not found in LCR
#
#  J0115.8+2519 existing
#
#  J0116.0-1136 existing
#
# Error: 4FGL J0116.0-2745 is not a source that is tracked by the LCR.
# 4FGL J0116.0-2745 not found in LCR
#
# Error: 4FGL J0116.2-6153 is not a source that is tracked by the LCR.
# 4FGL J0116.2-6153 not found in LCR
#
# Error: 4FGL J0116.5-2812 is not a source that is tracked by the LCR.
# 4FGL J0116.5-2812 not found in LCR
#
# Error: 4FGL J0116.5-3046 is not a source that is tracked by the LCR.
# 4FGL J0116.5-3046 not found in LCR
#
# Error: 4FGL J0116.8+6914 is not a source that is tracked by the LCR.
# 4FGL J0116.8+6914 not found in LCR
#
# Error: 4FGL J0117.5-2442 is not a source that is tracked by the LCR.
# 4FGL J0117.5-2442 not found in LCR
#
#  J0117.8-2109 existing
#
# Error: 4FGL J0117.9+1430 is not a source that is tracked by the LCR.
# 4FGL J0117.9+1430 not found in LCR
#
#  J0118.3-6008 existing
#
#  J0118.7-0848 existing
#
#  J0118.9-2141 existing
#
# Error: 4FGL J0119.0-1458 is not a source that is tracked by the LCR.
# 4FGL J0119.0-1458 not found in LCR
#
# Error: 4FGL J0119.4-5354 is not a source that is tracked by the LCR.
# 4FGL J0119.4-5354 not found in LCR
#
# Error: 4FGL J0119.6+4158 is not a source that is tracked by the LCR.
# 4FGL J0119.6+4158 not found in LCR
#
# Error: 4FGL J0119.9+4053 is not a source that is tracked by the LCR.
# 4FGL J0119.9+4053 not found in LCR
#
# Error: 4FGL J0120.1+0505 is not a source that is tracked by the LCR.
# 4FGL J0120.1+0505 not found in LCR
#
# Error: 4FGL J0120.2-7944 is not a source that is tracked by the LCR.
# 4FGL J0120.2-7944 not found in LCR
#
#  J0120.4-2701 existing
#
# Error: 4FGL J0121.4-7216 is not a source that is tracked by the LCR.
# 4FGL J0121.4-7216 not found in LCR
#
# Error: 4FGL J0121.5+7906 is not a source that is tracked by the LCR.
# 4FGL J0121.5+7906 not found in LCR
#
# Error: 4FGL J0121.7+5153 is not a source that is tracked by the LCR.
# 4FGL J0121.7+5153 not found in LCR
#
# Error: 4FGL J0121.8+1147 is not a source that is tracked by the LCR.
# 4FGL J0121.8+1147 not found in LCR
#
# Error: 4FGL J0121.8-3916 is not a source that is tracked by the LCR.
# 4FGL J0121.8-3916 not found in LCR
#
# Error: 4FGL J0122.1-3004 is not a source that is tracked by the LCR.
# 4FGL J0122.1-3004 not found in LCR
#
# Error: 4FGL J0122.4+1034 is not a source that is tracked by the LCR.
# 4FGL J0122.4+1034 not found in LCR
#
# Error: 4FGL J0122.4-1509 is not a source that is tracked by the LCR.
# 4FGL J0122.4-1509 not found in LCR
#
# Error: 4FGL J0123.1+3421 is not a source that is tracked by the LCR.
# 4FGL J0123.1+3421 not found in LCR
#
# Error: 4FGL J0123.7+4209 is not a source that is tracked by the LCR.
# 4FGL J0123.7+4209 not found in LCR
#
# Error: 4FGL J0123.7-2311 is not a source that is tracked by the LCR.
# 4FGL J0123.7-2311 not found in LCR
#
# Error: 4FGL J0123.7-4129 is not a source that is tracked by the LCR.
# 4FGL J0123.7-4129 not found in LCR
#
# Error: 4FGL J0124.0+3035 is not a source that is tracked by the LCR.
# 4FGL J0124.0+3035 not found in LCR
#
#  J0124.8-0625 existing
#
# Error: 4FGL J0125.3+6820 is not a source that is tracked by the LCR.
# 4FGL J0125.3+6820 not found in LCR
#
# Error: 4FGL J0125.3-5112 is not a source that is tracked by the LCR.
# 4FGL J0125.3-5112 not found in LCR
#
#  J0125.3-2548 existing
#
# Error: 4FGL J0125.4+3200 is not a source that is tracked by the LCR.
# 4FGL J0125.4+3200 not found in LCR
#
# Error: 4FGL J0125.7-0015 is not a source that is tracked by the LCR.
# 4FGL J0125.7-0015 not found in LCR
#
# Error: 4FGL J0125.8-6348 is not a source that is tracked by the LCR.
# 4FGL J0125.8-6348 not found in LCR
#
# Error: 4FGL J0125.8+2605 is not a source that is tracked by the LCR.
# 4FGL J0125.8+2605 not found in LCR
#
# Error: 4FGL J0125.9-6303 is not a source that is tracked by the LCR.
# 4FGL J0125.9-6303 not found in LCR
#
#  J0126.0-2221 existing
#
# Error: 4FGL J0126.3-6746 is not a source that is tracked by the LCR.
# 4FGL J0126.3-6746 not found in LCR
#
# Error: 4FGL J0126.5-1553 is not a source that is tracked by the LCR.
# 4FGL J0126.5-1553 not found in LCR
#
#  J0126.8+2412 existing
#
# Error: 4FGL J0127.1+3310 is not a source that is tracked by the LCR.
# 4FGL J0127.1+3310 not found in LCR
#
# Error: 4FGL J0127.2-0819 is not a source that is tracked by the LCR.
# 4FGL J0127.2-0819 not found in LCR
#
#  J0127.2+0324 existing
#
# Error: 4FGL J0127.3-0148 is not a source that is tracked by the LCR.
# 4FGL J0127.3-0148 not found in LCR
#
# Error: 4FGL J0127.4-4813 is not a source that is tracked by the LCR.
# 4FGL J0127.4-4813 not found in LCR
#
# Error: 4FGL J0127.9+4857 is not a source that is tracked by the LCR.
# 4FGL J0127.9+4857 not found in LCR
#
# Error: 4FGL J0127.9+1737 is not a source that is tracked by the LCR.
# 4FGL J0127.9+1737 not found in LCR
#
# Error: 4FGL J0128.1+7542 is not a source that is tracked by the LCR.
# 4FGL J0128.1+7542 not found in LCR
#
# Error: 4FGL J0128.2-1722 is not a source that is tracked by the LCR.
# 4FGL J0128.2-1722 not found in LCR
#
# Error: 4FGL J0128.2+4400 is not a source that is tracked by the LCR.
# 4FGL J0128.2+4400 not found in LCR
#
# Error: 4FGL J0128.3+5710 is not a source that is tracked by the LCR.
# 4FGL J0128.3+5710 not found in LCR
#
# Error: 4FGL J0128.4+2614 is not a source that is tracked by the LCR.
# 4FGL J0128.4+2614 not found in LCR
#
#  J0128.5+4440 existing
#
# Error: 4FGL J0128.8-4626 is not a source that is tracked by the LCR.
# 4FGL J0128.8-4626 not found in LCR
#
# Error: 4FGL J0129.0+6312 is not a source that is tracked by the LCR.
# 4FGL J0129.0+6312 not found in LCR
#
# Error: 4FGL J0129.7+3436 is not a source that is tracked by the LCR.
# 4FGL J0129.7+3436 not found in LCR
#
# Error: 4FGL J0129.8+1440 is not a source that is tracked by the LCR.
# 4FGL J0129.8+1440 not found in LCR
#
# Error: 4FGL J0130.4-2129 is not a source that is tracked by the LCR.
# 4FGL J0130.4-2129 not found in LCR
#
# Error: 4FGL J0130.6+1844 is not a source that is tracked by the LCR.
# 4FGL J0130.6+1844 not found in LCR
#
#  J0131.1+6120 existing
#
# Error: 4FGL J0131.2+5547 is not a source that is tracked by the LCR.
# 4FGL J0131.2+5547 not found in LCR
#
# Error: 4FGL J0131.7-5346 is not a source that is tracked by the LCR.
# 4FGL J0131.7-5346 not found in LCR
#
#  J0132.1-0956 existing
#
#  J0132.7-1654 existing
#
# Error: 4FGL J0132.7-0804 is not a source that is tracked by the LCR.
# 4FGL J0132.7-0804 not found in LCR
#
# Error: 4FGL J0132.8-4413 is not a source that is tracked by the LCR.
# 4FGL J0132.8-4413 not found in LCR
#
# Error: 4FGL J0132.8+4324 is not a source that is tracked by the LCR.
# 4FGL J0132.8+4324 not found in LCR
#
# Error: 4FGL J0132.9-4259 is not a source that is tracked by the LCR.
# 4FGL J0132.9-4259 not found in LCR
#
# Error: 4FGL J0133.0+5931 is not a source that is tracked by the LCR.
# 4FGL J0133.0+5931 not found in LCR
#
#  J0133.1-5201 existing
#
# Error: 4FGL J0133.2-4533 is not a source that is tracked by the LCR.
# 4FGL J0133.2-4533 not found in LCR
#
# Error: 4FGL J0133.7-3409 is not a source that is tracked by the LCR.
# 4FGL J0133.7-3409 not found in LCR
#
# Error: 4FGL J0133.7-5527 is not a source that is tracked by the LCR.
# 4FGL J0133.7-5527 not found in LCR
#
#  J0134.3-3842 existing
#
# Error: 4FGL J0134.5+2637 is not a source that is tracked by the LCR.
# 4FGL J0134.5+2637 not found in LCR
#
# Error: 4FGL J0135.0+5338 is not a source that is tracked by the LCR.
# 4FGL J0135.0+5338 not found in LCR
#
# Error: 4FGL J0135.1+0255 is not a source that is tracked by the LCR.
# 4FGL J0135.1+0255 not found in LCR
#
# Error: 4FGL J0135.3-2728 is not a source that is tracked by the LCR.
# 4FGL J0135.3-2728 not found in LCR
#
# Error: 4FGL J0136.2-4708 is not a source that is tracked by the LCR.
# 4FGL J0136.2-4708 not found in LCR
#
# Error: 4FGL J0136.4+6911 is not a source that is tracked by the LCR.
# 4FGL J0136.4+6911 not found in LCR
#
#  J0136.5+3906 existing
#
# Error: 4FGL J0136.6+3130 is not a source that is tracked by the LCR.
# 4FGL J0136.6+3130 not found in LCR
#
# Error: 4FGL J0136.8+2032 is not a source that is tracked by the LCR.
# 4FGL J0136.8+2032 not found in LCR
#
#  J0137.0+4751 existing
#
# Error: 4FGL J0137.3-3239 is not a source that is tracked by the LCR.
# 4FGL J0137.3-3239 not found in LCR
#
# Error: 4FGL J0137.5+0847 is not a source that is tracked by the LCR.
# 4FGL J0137.5+0847 not found in LCR
#
#  J0137.6-2430 existing
#
#  J0137.9+5814 existing
#
#  J0138.0+2247 existing
#
# Error: 4FGL J0138.5+3931 is not a source that is tracked by the LCR.
# 4FGL J0138.5+3931 not found in LCR
#
# Error: 4FGL J0138.5+0300 is not a source that is tracked by the LCR.
# 4FGL J0138.5+0300 not found in LCR
#
# Error: 4FGL J0138.5-4613 is not a source that is tracked by the LCR.
# 4FGL J0138.5-4613 not found in LCR
#
# Error: 4FGL J0138.6+2923 is not a source that is tracked by the LCR.
# 4FGL J0138.6+2923 not found in LCR
#
# Error: 4FGL J0138.6+6821 is not a source that is tracked by the LCR.
# 4FGL J0138.6+6821 not found in LCR
#
# Error: 4FGL J0139.0+2601 is not a source that is tracked by the LCR.
# 4FGL J0139.0+2601 not found in LCR
#
# Error: 4FGL J0139.2-1705 is not a source that is tracked by the LCR.
# 4FGL J0139.2-1705 not found in LCR
#
# Error: 4FGL J0139.5-2228 is not a source that is tracked by the LCR.
# 4FGL J0139.5-2228 not found in LCR
#
# Error: 4FGL J0140.3+7054 is not a source that is tracked by the LCR.
# 4FGL J0140.3+7054 not found in LCR
#
# Error: 4FGL J0140.4+5114 is not a source that is tracked by the LCR.
# 4FGL J0140.4+5114 not found in LCR
#
# Error: 4FGL J0140.5-4730 is not a source that is tracked by the LCR.
# 4FGL J0140.5-4730 not found in LCR
#
# Error: 4FGL J0140.6-0758 is not a source that is tracked by the LCR.
# 4FGL J0140.6-0758 not found in LCR
#
#  J0140.6+8736 existing
#
#  J0141.4-0928 existing
#
# Error: 4FGL J0142.5+6650 is not a source that is tracked by the LCR.
# 4FGL J0142.5+6650 not found in LCR
#
# Error: 4FGL J0142.7-0543 is not a source that is tracked by the LCR.
# 4FGL J0142.7-0543 not found in LCR
#
#  J0143.1-3622 existing
#
# Error: 4FGL J0143.3-0119 is not a source that is tracked by the LCR.
# 4FGL J0143.3-0119 not found in LCR
#
# Error: 4FGL J0143.5-3156 is not a source that is tracked by the LCR.
# 4FGL J0143.5-3156 not found in LCR
#
#  J0143.7-5846 existing
#
# Error: 4FGL J0143.8+4947 is not a source that is tracked by the LCR.
# 4FGL J0143.8+4947 not found in LCR
#
# Error: 4FGL J0144.3+5959 is not a source that is tracked by the LCR.
# 4FGL J0144.3+5959 not found in LCR
#
#  J0144.6+2705 existing
#
#  J0145.0-2732 existing
#
# Error: 4FGL J0145.9+2319 is not a source that is tracked by the LCR.
# 4FGL J0145.9+2319 not found in LCR
#
#  J0146.0-6746 existing
#
# Error: 4FGL J0146.3+4606 is not a source that is tracked by the LCR.
# 4FGL J0146.3+4606 not found in LCR
#
# Error: 4FGL J0146.9-5202 is not a source that is tracked by the LCR.
# 4FGL J0146.9-5202 not found in LCR
#
# Error: 4FGL J0147.6+1547 is not a source that is tracked by the LCR.
# 4FGL J0147.6+1547 not found in LCR
#
# Error: 4FGL J0147.6-6028 is not a source that is tracked by the LCR.
# 4FGL J0147.6-6028 not found in LCR
#
# Error: 4FGL J0147.6-0825 is not a source that is tracked by the LCR.
# 4FGL J0147.6-0825 not found in LCR
#
# Error: 4FGL J0147.7-1321 is not a source that is tracked by the LCR.
# 4FGL J0147.7-1321 not found in LCR
#
# Error: 4FGL J0148.2+5201 is not a source that is tracked by the LCR.
# 4FGL J0148.2+5201 not found in LCR
#
# Error: 4FGL J0148.6+0127 is not a source that is tracked by the LCR.
# 4FGL J0148.6+0127 not found in LCR
#
# Error: 4FGL J0149.6-0734 is not a source that is tracked by the LCR.
# 4FGL J0149.6-0734 not found in LCR
#
# Error: 4FGL J0149.8+2650 is not a source that is tracked by the LCR.
# 4FGL J0149.8+2650 not found in LCR
#
# Error: 4FGL J0150.4+4848 is not a source that is tracked by the LCR.
# 4FGL J0150.4+4848 not found in LCR
#
# Error: 4FGL J0150.5-3337 is not a source that is tracked by the LCR.
# 4FGL J0150.5-3337 not found in LCR
#
# Error: 4FGL J0150.6-5448 is not a source that is tracked by the LCR.
# 4FGL J0150.6-5448 not found in LCR
#
# Error: 4FGL J0150.9+1230 is not a source that is tracked by the LCR.
# 4FGL J0150.9+1230 not found in LCR
#
# Error: 4FGL J0151.0+0539 is not a source that is tracked by the LCR.
# 4FGL J0151.0+0539 not found in LCR
#
# Error: 4FGL J0151.3+8601 is not a source that is tracked by the LCR.
# 4FGL J0151.3+8601 not found in LCR
#
# Error: 4FGL J0151.4-3607 is not a source that is tracked by the LCR.
# 4FGL J0151.4-3607 not found in LCR
#
# Error: 4FGL J0151.7+5455 is not a source that is tracked by the LCR.
# 4FGL J0151.7+5455 not found in LCR
#
#  J0152.2+3714 existing
#
#  J0152.2+2206 existing
#
#  J0152.6+0147 existing
#
# Error: 4FGL J0152.6-1404 is not a source that is tracked by the LCR.
# 4FGL J0152.6-1404 not found in LCR
#
# Error: 4FGL J0152.9-1109 is not a source that is tracked by the LCR.
# 4FGL J0152.9-1109 not found in LCR
#
# Error: 4FGL J0153.0+7517 is not a source that is tracked by the LCR.
# 4FGL J0153.0+7517 not found in LCR
#
# Error: 4FGL J0153.3+5416 is not a source that is tracked by the LCR.
# 4FGL J0153.3+5416 not found in LCR
#
# Error: 4FGL J0153.3-1845 is not a source that is tracked by the LCR.
# 4FGL J0153.3-1845 not found in LCR
#
# Error: 4FGL J0153.4+7114 is not a source that is tracked by the LCR.
# 4FGL J0153.4+7114 not found in LCR
#
# Error: 4FGL J0153.5-5107 is not a source that is tracked by the LCR.
# 4FGL J0153.5-5107 not found in LCR
#
#  J0153.9+0823 existing
#
# Error: 4FGL J0154.3-0236 is not a source that is tracked by the LCR.
# 4FGL J0154.3-0236 not found in LCR
#
# Error: 4FGL J0154.5-6604 is not a source that is tracked by the LCR.
# 4FGL J0154.5-6604 not found in LCR
#
# Error: 4FGL J0154.6+0051 is not a source that is tracked by the LCR.
# 4FGL J0154.6+0051 not found in LCR
#
# Error: 4FGL J0155.0+4433 is not a source that is tracked by the LCR.
# 4FGL J0155.0+4433 not found in LCR
#
# Error: 4FGL J0155.4-0625 is not a source that is tracked by the LCR.
# 4FGL J0155.4-0625 not found in LCR
#
# Error: 4FGL J0155.5+2920 is not a source that is tracked by the LCR.
# 4FGL J0155.5+2920 not found in LCR
#
# Error: 4FGL J0155.7+6642 is not a source that is tracked by the LCR.
# 4FGL J0155.7+6642 not found in LCR
#
# Error: 4FGL J0156.1+1502 is not a source that is tracked by the LCR.
# 4FGL J0156.1+1502 not found in LCR
#
#  J0156.3-2420 existing
#
#  J0156.5+3914 existing
#
# Error: 4FGL J0156.6-1758 is not a source that is tracked by the LCR.
# 4FGL J0156.6-1758 not found in LCR
#
#  J0156.8-4744 existing
#
#  J0156.9-5301 existing
#
# Error: 4FGL J0156.9+4648 is not a source that is tracked by the LCR.
# 4FGL J0156.9+4648 not found in LCR
#
# Error: 4FGL J0156.9-3235 is not a source that is tracked by the LCR.
# 4FGL J0156.9-3235 not found in LCR
#
# Error: 4FGL J0157.6+1012 is not a source that is tracked by the LCR.
# 4FGL J0157.6+1012 not found in LCR
#
#  J0157.7-4614 existing
#
# Error: 4FGL J0158.2+2515 is not a source that is tracked by the LCR.
# 4FGL J0158.2+2515 not found in LCR
#
# Error: 4FGL J0158.4+1230 is not a source that is tracked by the LCR.
# 4FGL J0158.4+1230 not found in LCR
#
# Error: 4FGL J0158.5-5005 is not a source that is tracked by the LCR.
# 4FGL J0158.5-5005 not found in LCR
#
# Error: 4FGL J0158.5+6058 is not a source that is tracked by the LCR.
# 4FGL J0158.5+6058 not found in LCR
#
# Error: 4FGL J0158.5+0549 is not a source that is tracked by the LCR.
# 4FGL J0158.5+0549 not found in LCR
#
#  J0158.5-3932 existing
#
# Error: 4FGL J0158.8+0101 is not a source that is tracked by the LCR.
# 4FGL J0158.8+0101 not found in LCR
#
# Error: 4FGL J0158.9+7037 is not a source that is tracked by the LCR.
# 4FGL J0158.9+7037 not found in LCR
#
# Error: 4FGL J0159.0-4255 is not a source that is tracked by the LCR.
# 4FGL J0159.0-4255 not found in LCR
#
#  J0159.0+3313 existing
#
#  J0159.3-4523 existing
#
#  J0159.5+1046 existing
#
# Error: 4FGL J0159.7-2740 is not a source that is tracked by the LCR.
# 4FGL J0159.7-2740 not found in LCR
#
# Error: 4FGL J0159.8-2234 is not a source that is tracked by the LCR.
# 4FGL J0159.8-2234 not found in LCR
#
# Error: 4FGL J0200.3-4109 is not a source that is tracked by the LCR.
# 4FGL J0200.3-4109 not found in LCR
#
#  J0200.6-6637 existing
#
# Error: 4FGL J0201.1+0036 is not a source that is tracked by the LCR.
# 4FGL J0201.1+0036 not found in LCR
#
# Error: 4FGL J0201.1-4347 is not a source that is tracked by the LCR.
# 4FGL J0201.1-4347 not found in LCR
#
# Error: 4FGL J0202.1+3939 is not a source that is tracked by the LCR.
# 4FGL J0202.1+3939 not found in LCR
#
# Error: 4FGL J0202.3-0605 is not a source that is tracked by the LCR.
# 4FGL J0202.3-0605 not found in LCR
#
# Error: 4FGL J0202.3-3531 is not a source that is tracked by the LCR.
# 4FGL J0202.3-3531 not found in LCR
#
# Error: 4FGL J0202.4+0849 is not a source that is tracked by the LCR.
# 4FGL J0202.4+0849 not found in LCR
#
# Error: 4FGL J0202.4+2943 is not a source that is tracked by the LCR.
# 4FGL J0202.4+2943 not found in LCR
#
# Error: 4FGL J0202.6-0258 is not a source that is tracked by the LCR.
# 4FGL J0202.6-0258 not found in LCR
#
#  J0202.7+4204 existing
#
# Error: 4FGL J0202.7+3133 is not a source that is tracked by the LCR.
# 4FGL J0202.7+3133 not found in LCR
#
# Error: 4FGL J0202.9-0225 is not a source that is tracked by the LCR.
# 4FGL J0202.9-0225 not found in LCR
#
# Error: 4FGL J0203.3-2507 is not a source that is tracked by the LCR.
# 4FGL J0203.3-2507 not found in LCR
#
#  J0203.6+7233 existing
#
#  J0203.7+3042 existing
#
# Error: 4FGL J0203.9+5411 is not a source that is tracked by the LCR.
# 4FGL J0203.9+5411 not found in LCR
#
# Error: 4FGL J0203.9+8120 is not a source that is tracked by the LCR.
# 4FGL J0203.9+8120 not found in LCR
#
# Error: 4FGL J0204.0-3334 is not a source that is tracked by the LCR.
# 4FGL J0204.0-3334 not found in LCR
#
# Error: 4FGL J0204.1-2919 is not a source that is tracked by the LCR.
# 4FGL J0204.1-2919 not found in LCR
#
# Error: 4FGL J0204.3-3140 is not a source that is tracked by the LCR.
# 4FGL J0204.3-3140 not found in LCR
#
# Error: 4FGL J0204.3+2417 is not a source that is tracked by the LCR.
# 4FGL J0204.3+2417 not found in LCR
#
# Error: 4FGL J0204.7+6656 is not a source that is tracked by the LCR.
# 4FGL J0204.7+6656 not found in LCR
#
#  J0204.8+1513 existing
#
#  J0205.0-1700 existing
#
# Error: 4FGL J0205.2-3050 is not a source that is tracked by the LCR.
# 4FGL J0205.2-3050 not found in LCR
#
#  J0205.2+3212 existing
#
# Error: 4FGL J0205.6+6449 is not a source that is tracked by the LCR.
# 4FGL J0205.6+6449 not found in LCR
#
#  J0205.7+6449 existing
#
# Error: 4FGL J0206.0-0958 is not a source that is tracked by the LCR.
# 4FGL J0206.0-0958 not found in LCR
#
#  J0206.4-1151 existing
#
# Error: 4FGL J0206.4+3829 is not a source that is tracked by the LCR.
# 4FGL J0206.4+3829 not found in LCR
#
# Error: 4FGL J0206.8-5744 is not a source that is tracked by the LCR.
# 4FGL J0206.8-5744 not found in LCR
#
# Error: 4FGL J0207.2-1832 is not a source that is tracked by the LCR.
# 4FGL J0207.2-1832 not found in LCR
#
# Error: 4FGL J0207.4-3855 is not a source that is tracked by the LCR.
# 4FGL J0207.4-3855 not found in LCR
#
# Error: 4FGL J0207.4+5214 is not a source that is tracked by the LCR.
# 4FGL J0207.4+5214 not found in LCR
#
# Error: 4FGL J0207.5-1049 is not a source that is tracked by the LCR.
# 4FGL J0207.5-1049 not found in LCR
#
#  J0207.5-2402 existing
#
# Error: 4FGL J0207.9+2203 is not a source that is tracked by the LCR.
# 4FGL J0207.9+2203 not found in LCR
#
# Error: 4FGL J0207.9+0953 is not a source that is tracked by the LCR.
# 4FGL J0207.9+0953 not found in LCR
#
# Error: 4FGL J0208.3-6838 is not a source that is tracked by the LCR.
# 4FGL J0208.3-6838 not found in LCR
#
# Error: 4FGL J0208.5-0046 is not a source that is tracked by the LCR.
# 4FGL J0208.5-0046 not found in LCR
#
# Error: 4FGL J0208.6+3523 is not a source that is tracked by the LCR.
# 4FGL J0208.6+3523 not found in LCR
#
# Error: 4FGL J0209.3+4449 is not a source that is tracked by the LCR.
# 4FGL J0209.3+4449 not found in LCR
#
#  J0209.3-5228 existing
#
# Error: 4FGL J0209.7+6437 is not a source that is tracked by the LCR.
# 4FGL J0209.7+6437 not found in LCR
#
# Error: 4FGL J0209.8+2626 is not a source that is tracked by the LCR.
# 4FGL J0209.8+2626 not found in LCR
#
#  J0209.9+7229 existing
#
# Error: 4FGL J0210.1+2518 is not a source that is tracked by the LCR.
# ...
#
# Error: 4FGL J2317.0+3756 is not a source that is tracked by the LCR.
# 4FGL J2317.0+3756 not found in LCR
#
# Error: 4FGL J2317.3+1433 is not a source that is tracked by the LCR.
# 4FGL J2317.3+1433 not found in LCR
#
#  J2317.4-4533 existing
#
# Error: 4FGL J2317.6+6036 is not a source that is tracked by the LCR.
# 4FGL J2317.6+6036 not found in LCR
#
#  J2317.7+2839 existing
#
# Error: 4FGL J2317.8+6140 is not a source that is tracked by the LCR.
# 4FGL J2317.8+6140 not found in LCR
#
#  J2318.2+1915 existing
#
# Error: 4FGL J2318.6-3827 is not a source that is tracked by the LCR.
# 4FGL J2318.6-3827 not found in LCR
#
# Error: 4FGL J2318.6-1657 is not a source that is tracked by the LCR.
# 4FGL J2318.6-1657 not found in LCR
#
# Error: 4FGL J2318.9+4151 is not a source that is tracked by the LCR.
# 4FGL J2318.9+4151 not found in LCR
#
# Error: 4FGL J2319.0+5102 is not a source that is tracked by the LCR.
# 4FGL J2319.0+5102 not found in LCR
#
# Error: 4FGL J2319.1-4207 is not a source that is tracked by the LCR.
# 4FGL J2319.1-4207 not found in LCR
#
# Error: 4FGL J2319.6-0456 is not a source that is tracked by the LCR.
# 4FGL J2319.6-0456 not found in LCR
#
# Error: 4FGL J2319.7+1609 is not a source that is tracked by the LCR.
# 4FGL J2319.7+1609 not found in LCR
#
# Error: 4FGL J2320.1-2440 is not a source that is tracked by the LCR.
# 4FGL J2320.1-2440 not found in LCR
#
# Error: 4FGL J2320.2+0707 is not a source that is tracked by the LCR.
# 4FGL J2320.2+0707 not found in LCR
#
# Error: 4FGL J2320.7+6115 is not a source that is tracked by the LCR.
# 4FGL J2320.7+6115 not found in LCR
#
#  J2320.8-0823 existing
#
# Error: 4FGL J2321.0-6308 is not a source that is tracked by the LCR.
# 4FGL J2321.0-6308 not found in LCR
#
# Error: 4FGL J2321.0+2836 is not a source that is tracked by the LCR.
# 4FGL J2321.0+2836 not found in LCR
#
# Error: 4FGL J2321.4+5111 is not a source that is tracked by the LCR.
# 4FGL J2321.4+5111 not found in LCR
#
# Error: 4FGL J2321.4+6145 is not a source that is tracked by the LCR.
# 4FGL J2321.4+6145 not found in LCR
#
#  J2321.5-1619 existing
#
#  J2321.7-6438 existing
#
#  J2321.9+3204 existing
#
# Error: 4FGL J2321.9+2734 is not a source that is tracked by the LCR.
# 4FGL J2321.9+2734 not found in LCR
#
# Error: 4FGL J2321.9-4842 is not a source that is tracked by the LCR.
# 4FGL J2321.9-4842 not found in LCR
#
# Error: 4FGL J2322.1+4440 is not a source that is tracked by the LCR.
# 4FGL J2322.1+4440 not found in LCR
#
# Error: 4FGL J2322.3+2248 is not a source that is tracked by the LCR.
# 4FGL J2322.3+2248 not found in LCR
#
# Error: 4FGL J2322.4-2906 is not a source that is tracked by the LCR.
# 4FGL J2322.4-2906 not found in LCR
#
#  J2322.6-0735 existing
#
# Error: 4FGL J2322.7+3436 is not a source that is tracked by the LCR.
# 4FGL J2322.7+3436 not found in LCR
#
#  J2322.8-4916 existing
#
# Error: 4FGL J2322.8-4221 is not a source that is tracked by the LCR.
# 4FGL J2322.8-4221 not found in LCR
#
# Error: 4FGL J2323.1+2040 is not a source that is tracked by the LCR.
# 4FGL J2323.1+2040 not found in LCR
#
# Error: 4FGL J2323.4+5849 is not a source that is tracked by the LCR.
# 4FGL J2323.4+5849 not found in LCR
#
#  J2323.5-0317 existing
#
#  J2323.6-0617 existing
#
#  J2323.8+4210 existing
#
# Error: 4FGL J2323.9+2519 is not a source that is tracked by the LCR.
# 4FGL J2323.9+2519 not found in LCR
#
# Error: 4FGL J2323.9+6219 is not a source that is tracked by the LCR.
# 4FGL J2323.9+6219 not found in LCR
#
# Error: 4FGL J2324.5+7950 is not a source that is tracked by the LCR.
# 4FGL J2324.5+7950 not found in LCR
#
#  J2324.6+3115 existing
#
#  J2324.7-4041 existing
#
#  J2324.7+0801 existing
#
# Error: 4FGL J2325.2-2010 is not a source that is tracked by the LCR.
# 4FGL J2325.2-2010 not found in LCR
#
#  J2325.2+3957 existing
#
#  J2325.4-4800 existing
#
#  J2325.4-3559 existing
#
# Error: 4FGL J2325.6+1644 is not a source that is tracked by the LCR.
# 4FGL J2325.6+1644 not found in LCR
#
#  J2325.7+1821 existing
#
# Error: 4FGL J2325.9+6206 is not a source that is tracked by the LCR.
# 4FGL J2325.9+6206 not found in LCR
#
#  J2326.2+0113 existing
#
# Error: 4FGL J2326.5+6122 is not a source that is tracked by the LCR.
# 4FGL J2326.5+6122 not found in LCR
#
# Error: 4FGL J2326.9-0201 is not a source that is tracked by the LCR.
# 4FGL J2326.9-0201 not found in LCR
#
#  J2326.9-4130 existing
#
# Error: 4FGL J2327.3+4717 is not a source that is tracked by the LCR.
# 4FGL J2327.3+4717 not found in LCR
#
# Error: 4FGL J2327.4+0444 is not a source that is tracked by the LCR.
# 4FGL J2327.4+0444 not found in LCR
#
#  J2327.5-3259 existing
#
#  J2327.5+0939 existing
#
# Error: 4FGL J2327.8-5626 is not a source that is tracked by the LCR.
# 4FGL J2327.8-5626 not found in LCR
#
# Error: 4FGL J2328.0-2557 is not a source that is tracked by the LCR.
# 4FGL J2328.0-2557 not found in LCR
#
# Error: 4FGL J2328.2-4422 is not a source that is tracked by the LCR.
# 4FGL J2328.2-4422 not found in LCR
#
#  J2328.3-4036 existing
#
# Error: 4FGL J2328.8+4537 is not a source that is tracked by the LCR.
# 4FGL J2328.8+4537 not found in LCR
#
# Error: 4FGL J2329.0+0832 is not a source that is tracked by the LCR.
# 4FGL J2329.0+0832 not found in LCR
#
# Error: 4FGL J2329.2+3755 is not a source that is tracked by the LCR.
# 4FGL J2329.2+3755 not found in LCR
#
#  J2329.3-4955 existing
#
#  J2329.3-4733 existing
#
# Error: 4FGL J2329.7+6101 is not a source that is tracked by the LCR.
# 4FGL J2329.7+6101 not found in LCR
#
# Error: 4FGL J2329.7-2118 is not a source that is tracked by the LCR.
# 4FGL J2329.7-2118 not found in LCR
#
#  J2330.2+7759 existing
#
# Error: 4FGL J2330.3-2332 is not a source that is tracked by the LCR.
# 4FGL J2330.3-2332 not found in LCR
#
# Error: 4FGL J2330.3-2948 is not a source that is tracked by the LCR.
# 4FGL J2330.3-2948 not found in LCR
#
# Error: 4FGL J2330.4+1230 is not a source that is tracked by the LCR.
# 4FGL J2330.4+1230 not found in LCR
#
#  J2330.5+1102 existing
#
# Error: 4FGL J2330.5-2445 is not a source that is tracked by the LCR.
# 4FGL J2330.5-2445 not found in LCR
#
# Error: 4FGL J2330.6-3726 is not a source that is tracked by the LCR.
# 4FGL J2330.6-3726 not found in LCR
#
#  J2331.0-2147 existing
#
# Error: 4FGL J2331.1-1653 is not a source that is tracked by the LCR.
# 4FGL J2331.1-1653 not found in LCR
#
# Error: 4FGL J2331.2-3839 is not a source that is tracked by the LCR.
# 4FGL J2331.2-3839 not found in LCR
#
#  J2331.3-1558 existing
#
# Error: 4FGL J2331.5-0258 is not a source that is tracked by the LCR.
# 4FGL J2331.5-0258 not found in LCR
#
# Error: 4FGL J2331.6+4430 is not a source that is tracked by the LCR.
# 4FGL J2331.6+4430 not found in LCR
#
# Error: 4FGL J2332.1-4118 is not a source that is tracked by the LCR.
# 4FGL J2332.1-4118 not found in LCR
#
# Error: 4FGL J2333.1-5527 is not a source that is tracked by the LCR.
# 4FGL J2333.1-5527 not found in LCR
#
# Error: 4FGL J2333.4-0133 is not a source that is tracked by the LCR.
# 4FGL J2333.4-0133 not found in LCR
#
# Error: 4FGL J2333.9-2343 is not a source that is tracked by the LCR.
# 4FGL J2333.9-2343 not found in LCR
#
# Error: 4FGL J2334.0-2528 is not a source that is tracked by the LCR.
# 4FGL J2334.0-2528 not found in LCR
#
#  J2334.2+0736 existing
#
#  J2334.8+1432 existing
#
# Error: 4FGL J2335.4-2345 is not a source that is tracked by the LCR.
# 4FGL J2335.4-2345 not found in LCR
#
#  J2335.4-0128 existing
#
# Error: 4FGL J2335.9-5811 is not a source that is tracked by the LCR.
# 4FGL J2335.9-5811 not found in LCR
#
# Error: 4FGL J2336.2-3136 is not a source that is tracked by the LCR.
# 4FGL J2336.2-3136 not found in LCR
#
# Error: 4FGL J2336.2-0715 is not a source that is tracked by the LCR.
# 4FGL J2336.2-0715 not found in LCR
#
#  J2336.5-7622 existing
#
# Error: 4FGL J2336.6+2356 is not a source that is tracked by the LCR.
# 4FGL J2336.6+2356 not found in LCR
#
#  J2336.6-4115 existing
#
# Error: 4FGL J2336.9-8427 is not a source that is tracked by the LCR.
# 4FGL J2336.9-8427 not found in LCR
#
# Error: 4FGL J2336.9-5859 is not a source that is tracked by the LCR.
# 4FGL J2336.9-5859 not found in LCR
#
# Error: 4FGL J2337.7+1449 is not a source that is tracked by the LCR.
# 4FGL J2337.7+1449 not found in LCR
#
# Error: 4FGL J2337.7-2903 is not a source that is tracked by the LCR.
# 4FGL J2337.7-2903 not found in LCR
#
#  J2338.0-0230 existing
#
# Error: 4FGL J2338.1+0325 is not a source that is tracked by the LCR.
# 4FGL J2338.1+0325 not found in LCR
#
# Error: 4FGL J2338.1+0411 is not a source that is tracked by the LCR.
# 4FGL J2338.1+0411 not found in LCR
#
# Error: 4FGL J2338.9+2124 is not a source that is tracked by the LCR.
# 4FGL J2338.9+2124 not found in LCR
#
# Error: 4FGL J2339.2-7403 is not a source that is tracked by the LCR.
# 4FGL J2339.2-7403 not found in LCR
#
# Error: 4FGL J2339.3-2656 is not a source that is tracked by the LCR.
# 4FGL J2339.3-2656 not found in LCR
#
# Error: 4FGL J2339.4+3008 is not a source that is tracked by the LCR.
# 4FGL J2339.4+3008 not found in LCR
#
#  J2339.6+0242 existing
#
# Error: 4FGL J2339.6-0533 is not a source that is tracked by the LCR.
# 4FGL J2339.6-0533 not found in LCR
#
# Error: 4FGL J2340.5+3854 is not a source that is tracked by the LCR.
# 4FGL J2340.5+3854 not found in LCR
#
# Error: 4FGL J2340.8+8015 is not a source that is tracked by the LCR.
# 4FGL J2340.8+8015 not found in LCR
#
# Error: 4FGL J2341.8-2917 is not a source that is tracked by the LCR.
# 4FGL J2341.8-2917 not found in LCR
#
# Error: 4FGL J2342.4-4739 is not a source that is tracked by the LCR.
# 4FGL J2342.4-4739 not found in LCR
#
# Error: 4FGL J2342.7+3154 is not a source that is tracked by the LCR.
# 4FGL J2342.7+3154 not found in LCR
#
# Error: 4FGL J2343.0-4756 is not a source that is tracked by the LCR.
# 4FGL J2343.0-4756 not found in LCR
#
# Error: 4FGL J2343.6+3438 is not a source that is tracked by the LCR.
# 4FGL J2343.6+3438 not found in LCR
#
#  J2343.7-5624 existing
#
# Error: 4FGL J2343.9+1539 is not a source that is tracked by the LCR.
# 4FGL J2343.9+1539 not found in LCR
#
# Error: 4FGL J2343.9+0546 is not a source that is tracked by the LCR.
# 4FGL J2343.9+0546 not found in LCR
#
# Error: 4FGL J2344.7-4234 is not a source that is tracked by the LCR.
# 4FGL J2344.7-4234 not found in LCR
#
#  J2345.2-1555 existing
#
# Error: 4FGL J2345.9+3413 is not a source that is tracked by the LCR.
# 4FGL J2345.9+3413 not found in LCR
#
# Error: 4FGL J2346.2-4322 is not a source that is tracked by the LCR.
# 4FGL J2346.2-4322 not found in LCR
#
# Error: 4FGL J2346.7+0705 is not a source that is tracked by the LCR.
# 4FGL J2346.7+0705 not found in LCR
#
# Error: 4FGL J2346.7+8008 is not a source that is tracked by the LCR.
# 4FGL J2346.7+8008 not found in LCR
#
# Error: 4FGL J2347.0-5720 is not a source that is tracked by the LCR.
# 4FGL J2347.0-5720 not found in LCR
#
#  J2347.0+5141 existing
#
# Error: 4FGL J2347.8+6256 is not a source that is tracked by the LCR.
# 4FGL J2347.8+6256 not found in LCR
#
# Error: 4FGL J2347.9+5436 is not a source that is tracked by the LCR.
# 4FGL J2347.9+5436 not found in LCR
#
#  J2347.9-5106 existing
#
#  J2348.0-1630 existing
#
#  J2348.1-4934 existing
#
# Error: 4FGL J2348.3-6049 is not a source that is tracked by the LCR.
# 4FGL J2348.3-6049 not found in LCR
#
# Error: 4FGL J2348.6-0426 is not a source that is tracked by the LCR.
# 4FGL J2348.6-0426 not found in LCR
#
# Error: 4FGL J2348.6-2054 is not a source that is tracked by the LCR.
# 4FGL J2348.6-2054 not found in LCR
#
#  J2349.2+4535 existing
#
#  J2349.4+0534 existing
#
# Error: 4FGL J2350.0+2622 is not a source that is tracked by the LCR.
# 4FGL J2350.0+2622 not found in LCR
#
# Error: 4FGL J2350.4-0559 is not a source that is tracked by the LCR.
# 4FGL J2350.4-0559 not found in LCR
#
# Error: 4FGL J2350.5-3930 is not a source that is tracked by the LCR.
# 4FGL J2350.5-3930 not found in LCR
#
#  J2350.6-3005 existing
#
# Error: 4FGL J2350.7+6738 is not a source that is tracked by the LCR.
# 4FGL J2350.7+6738 not found in LCR
#
# Error: 4FGL J2350.9-1416 is not a source that is tracked by the LCR.
# 4FGL J2350.9-1416 not found in LCR
#
# Error: 4FGL J2351.3-7559 is not a source that is tracked by the LCR.
# 4FGL J2351.3-7559 not found in LCR
#
# Error: 4FGL J2351.3+3913 is not a source that is tracked by the LCR.
# 4FGL J2351.3+3913 not found in LCR
#
# Error: 4FGL J2351.4-2818 is not a source that is tracked by the LCR.
# 4FGL J2351.4-2818 not found in LCR
#
# Error: 4FGL J2351.7-3416 is not a source that is tracked by the LCR.
# 4FGL J2351.7-3416 not found in LCR
#
#  J2352.0+1750 existing
#
# Error: 4FGL J2352.1-4301 is not a source that is tracked by the LCR.
# 4FGL J2352.1-4301 not found in LCR
#
# Error: 4FGL J2352.7+6027 is not a source that is tracked by the LCR.
# 4FGL J2352.7+6027 not found in LCR
#
# Error: 4FGL J2352.9+3031 is not a source that is tracked by the LCR.
# 4FGL J2352.9+3031 not found in LCR
#
# Error: 4FGL J2353.1-4806 is not a source that is tracked by the LCR.
# 4FGL J2353.1-4806 not found in LCR
#
#  J2353.2+3135 existing
#
# Error: 4FGL J2353.5+6646 is not a source that is tracked by the LCR.
# 4FGL J2353.5+6646 not found in LCR
#
# Error: 4FGL J2353.5-1457 is not a source that is tracked by the LCR.
# 4FGL J2353.5-1457 not found in LCR
#
# Error: 4FGL J2353.7-3037 is not a source that is tracked by the LCR.
# 4FGL J2353.7-3037 not found in LCR
#
# Error: 4FGL J2353.8-3911 is not a source that is tracked by the LCR.
# 4FGL J2353.8-3911 not found in LCR
#
# Error: 4FGL J2354.1+2720 is not a source that is tracked by the LCR.
# 4FGL J2354.1+2720 not found in LCR
#
# Error: 4FGL J2354.1-0958 is not a source that is tracked by the LCR.
# 4FGL J2354.1-0958 not found in LCR
#
# Error: 4FGL J2354.6+4554 is not a source that is tracked by the LCR.
# 4FGL J2354.6+4554 not found in LCR
#
# Error: 4FGL J2354.9+8151 is not a source that is tracked by the LCR.
# 4FGL J2354.9+8151 not found in LCR
#
#  J2355.2-5247 existing
#
# Error: 4FGL J2355.2+6257 is not a source that is tracked by the LCR.
# 4FGL J2355.2+6257 not found in LCR
#
# Error: 4FGL J2355.5-6614 is not a source that is tracked by the LCR.
# 4FGL J2355.5-6614 not found in LCR
#
#  J2355.7-3351 existing
#
# Error: 4FGL J2356.2+4036 is not a source that is tracked by the LCR.
# 4FGL J2356.2+4036 not found in LCR
#
# Error: 4FGL J2357.0-4840 is not a source that is tracked by the LCR.
# 4FGL J2357.0-4840 not found in LCR
#
# Error: 4FGL J2357.4-0152 is not a source that is tracked by the LCR.
# 4FGL J2357.4-0152 not found in LCR
#
# Error: 4FGL J2357.4-1718 is not a source that is tracked by the LCR.
# 4FGL J2357.4-1718 not found in LCR
#
# Error: 4FGL J2357.7-1937 is not a source that is tracked by the LCR.
# 4FGL J2357.7-1937 not found in LCR
#
# Error: 4FGL J2357.7+6802 is not a source that is tracked by the LCR.
# 4FGL J2357.7+6802 not found in LCR
#
#  J2357.8-5311 existing
#
# Error: 4FGL J2357.8+6231 is not a source that is tracked by the LCR.
# 4FGL J2357.8+6231 not found in LCR
#
# Error: 4FGL J2357.8+6839 is not a source that is tracked by the LCR.
# 4FGL J2357.8+6839 not found in LCR
#
#  J2358.0-4601 existing
#
# Error: 4FGL J2358.1-2853 is not a source that is tracked by the LCR.
# 4FGL J2358.1-2853 not found in LCR
#
#  J2358.3-1021 existing
#
#  J2358.3+3830 existing
#
# Error: 4FGL J2358.4+6547 is not a source that is tracked by the LCR.
# 4FGL J2358.4+6547 not found in LCR
#
# Error: 4FGL J2358.5-1808 is not a source that is tracked by the LCR.
# 4FGL J2358.5-1808 not found in LCR
#
# Error: 4FGL J2358.7+5646 is not a source that is tracked by the LCR.
# 4FGL J2358.7+5646 not found in LCR
#
#  J2359.0+3922 existing
#
# Error: 4FGL J2359.0-3038 is not a source that is tracked by the LCR.
# 4FGL J2359.0-3038 not found in LCR
#
# Error: 4FGL J2359.1+1719 is not a source that is tracked by the LCR.
# 4FGL J2359.1+1719 not found in LCR
#
#  J2359.2-3134 existing
#
# Error: 4FGL J2359.3+0215 is not a source that is tracked by the LCR.
# 4FGL J2359.3+0215 not found in LCR
#
# Error: 4FGL J2359.3+2502 is not a source that is tracked by the LCR.
# 4FGL J2359.3+2502 not found in LCR
#
# Error: 4FGL J2359.3-2049 is not a source that is tracked by the LCR.
# 4FGL J2359.3-2049 not found in LCR
#
# Error: 4FGL J2359.3+1444 is not a source that is tracked by the LCR.
# 4FGL J2359.3+1444 not found in LCR
#
# Error: 4FGL J2359.7-5041 is not a source that is tracked by the LCR.
# 4FGL J2359.7-5041 not found in LCR
#
# Error: 4FGL J2359.9-3736 is not a source that is tracked by the LCR.
# 4FGL J2359.9-3736 not found in LCR
#
# Error: 4FGL J2359.9+3145 is not a source that is tracked by the LCR.
# 4FGL J2359.9+3145 not found in LCR
# Skipped 5695 sources out of 7195

# %%
print("Done")
print("Total number of sources ran: ",n_sources-skipped_sources)
# Out:
# Done
# Total number of sources ran:  1500

# %% [markdown]
# # First Derive the flux at ~1 MeV for all sources
#
# This is done by:
# - 1. Assuming that the best fit spectrum for the one is what is reported in the catalog
# - 2. Using the peak flux and peak enegy along with the spectrum interpolate it to 1 MeV

# %%
def spectral_model(spectrumtype,parameters,x):
    # Logic is that the Model goes like Flux (dn/de) = model()
    # Flux(x)/Flux(pivot_energy) = model(x)/model(pivot_energy)
    if spectrumtype=='LogParabola':
        pivot_eng =  parameters[0] #N
        pivot_flux = parameters[1] #E0
        alpha = parameters[2]
        beta =  parameters[3]
        # y = N * (x/eb)**(-alpha+beta*np.log(x/eb))
        y = pivot_flux*((x/pivot_eng)**(-alpha+beta*np.log(x/pivot_eng)))
        return y
    elif spectrumtype=='PLSuperExpCutoff':
        pivot_eng =  parameters[0]
        pivot_flux = parameters[1]
        index1 =     -1*parameters[2]
        expfactor =  parameters[3]
        index2 =     parameters[4]
        # y = N * (x**index1)*np.exp(-expfactor*(pivot_eng**index2-x**index2))
        y = pivot_flux*((x/pivot_eng)**index1)*np.exp(-expfactor*(pivot_eng**index2-x**index2))
        return y
    elif spectrumtype=='PowerLaw':
        pivot_eng =  parameters[0]
        pivot_flux = parameters[1]
        index =      parameters[2]
        # y = N * (x**index1)
        y = pivot_flux*((x/pivot_eng)**index)
        return y
    else:
        y = -1
        return y

# %%
flux_at_100_mev = []

for i in range(len(cat_4fgl_dr4_data['SpectrumType'])):
    energy_calc = 100 #MeV
    if cat_4fgl_dr4_data['SpectrumType'][i]==b'LogParabola      ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][i],\
                         cat_4fgl_dr4_data['LP_Flux_Density'][i],\
                         cat_4fgl_dr4_data['LP_Index'][i],\
                         cat_4fgl_dr4_data['LP_beta'][i]]
        y1 = spectral_model('LogParabola',parameters_arr,energy_calc)
    elif cat_4fgl_dr4_data['SpectrumType'][i]==b'PLSuperExpCutoff ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][i],\
                         cat_4fgl_dr4_data['PLEC_Flux_Density'][i],\
                         cat_4fgl_dr4_data['PLEC_IndexS'][i],\
                         cat_4fgl_dr4_data['PLEC_ExpfactorS'][i],\
                         cat_4fgl_dr4_data['PLEC_Exp_Index'][i]]
        y1 = spectral_model('PLSuperExpCutoff',parameters_arr,energy_calc)
    elif cat_4fgl_dr4_data['SpectrumType'][i]==b'PowerLaw         ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][i],\
                         cat_4fgl_dr4_data['PL_Flux_Density'][i],\
                         cat_4fgl_dr4_data['PL_Index'][i]]
        y1 = spectral_model('PowerLaw',parameters_arr,energy_calc)
    else:
        print("ERROR: SPECTRUM NOT FOUND!!!! for ",i,f'---> {cat_4fgl_dr4_data["SpectrumType"][i]}')
    flux_at_100_mev.append(y1)
    del y1
# No error means all the spectra are loaded!

print(np.amin(flux_at_100_mev))
# If you get -1 then spectrum is not loaded properly in definition somehow
# Out:
# 0.0

# %%
def get_y_from_energy(energy_calc,catalog_index):
    if cat_4fgl_dr4_data['SpectrumType'][catalog_index]==b'LogParabola      ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][catalog_index],\
                         cat_4fgl_dr4_data['LP_Flux_Density'][catalog_index],\
                         cat_4fgl_dr4_data['LP_Index'][catalog_index],\
                         cat_4fgl_dr4_data['LP_beta'][catalog_index]]
        y_res = spectral_model('LogParabola',parameters_arr,energy_calc)
    elif cat_4fgl_dr4_data['SpectrumType'][catalog_index]==b'PLSuperExpCutoff ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][catalog_index],\
                         cat_4fgl_dr4_data['PLEC_Flux_Density'][catalog_index],\
                         cat_4fgl_dr4_data['PLEC_IndexS'][catalog_index],\
                         cat_4fgl_dr4_data['PLEC_ExpfactorS'][catalog_index],\
                         cat_4fgl_dr4_data['PLEC_Exp_Index'][catalog_index]]
        y_res = spectral_model('PLSuperExpCutoff',parameters_arr,energy_calc)
    elif cat_4fgl_dr4_data['SpectrumType'][catalog_index]==b'PowerLaw         ':
        parameters_arr = [cat_4fgl_dr4_data['Pivot_Energy'][catalog_index],\
                         cat_4fgl_dr4_data['PL_Flux_Density'][catalog_index],\
                         cat_4fgl_dr4_data['PL_Index'][catalog_index]]
        y_res = spectral_model('PowerLaw',parameters_arr,energy_calc)
    else:
        print("ERROR: SPECTRUM NOT FOUND!!!! for ",i,f'---> {cat_4fgl_dr4_data["SpectrumType"][catalog_index]}')

    return y_res

# %%
integrated_flux_vals = []
for i in range(len(cat_4fgl_dr4_data['SpectrumType'])):
    flux_arr= []
    for e_val in [0.1,0.5,1,5,10,50,100,500]:
        y_val = get_y_from_energy(e_val,i)
        if y_val<=1e-20 or y_val>=1e4:
            y_val=0
        flux_arr.append(y_val)
    integrated_flux_vals.append(flux_arr)
    
# No error means all the spectra are loaded!

# %%
for i in range(len(integrated_flux_vals)):
    plt.plot([0.1,0.5,1,5,10,50,100,500],integrated_flux_vals[i])
    plt.yscale("log")

# %%
# Make Aitoff plot to see how this looks like at different energies,
# and use AMEGO sensitivity to see how much will be seen.....


#for i in range(len(cat_4fgl_dr4_data['SpectrumType'])):

# %%
# Setup for Aitoff from SNUGGY
"""
gal_coords1 = arr[2]
ra = gal_coords1.l.wrap_at(180 * u.deg).radian
dec = gal_coords1.b.wrap_at(180 * u.deg).radian#z_list = arr_with_flux[1]/sum(arr_with_flux[1])
z_list = 10**arr_with_flux[1]
z_list=z_list/sum(z_list)

coords = gal_coords1


fig = plt.figure(figsize=(20,10),dpi=250)
ax= fig.add_subplot(111, projection='aitoff')
ax.set_facecolor("Ivory")
image = plt.scatter(coords.l.wrap_at('180d').radian, coords.b.radian, c=z_list, cmap='plasma', norm=colors.LogNorm(vmax=np.nanmax(z_list)))
#plt.legend(loc="lower right")

plt.xlabel('l')
plt.ylabel('b.')
plt.grid(True)
plt.colorbar(image, spacing='uniform',label="Neutrino Flux",ticks=[0,1])
"""
# Out:
# '\ngal_coords1 = arr[2]\nra = gal_coords1.l.wrap_at(180 * u.deg).radian\ndec = gal_coords1.b.wrap_at(180 * u.deg).radian#z_list = arr_with_flux[1]/sum(arr_with_flux[1])\nz_list = 10**arr_with_flux[1]\nz_list=z_list/sum(z_list)\n\ncoords = gal_coords1\n\n\nfig = plt.figure(figsize=(20,10),dpi=250)\nax= fig.add_subplot(111, projection=\'aitoff\')\nax.set_facecolor("Ivory")\nimage = plt.scatter(coords.l.wrap_at(\'180d\').radian, coords.b.radian, c=z_list, cmap=\'plasma\', norm=colors.LogNorm(vmax=np.nanmax(z_list)))\n#plt.legend(loc="lower right")\n\nplt.xlabel(\'l\')\nplt.ylabel(\'b.\')\nplt.grid(True)\nplt.colorbar(image, spacing=\'uniform\',label="Neutrino Flux",ticks=[0,1])\n'

# %%
# Check

"""fsrq_4fgl_indices = []
ts_4fgl_fsrq_300_1000 = []
for i in range(len(cat_4fgl_dr3_data['CLASS1'])):
    if cat_4fgl_dr3_data['CLASS1'][i]==b'fsrq ' or cat_4fgl_dr3_data['CLASS1'][i]==b'FSRQ ':
        fsrq_4fgl_indices.append(i)
        if cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i]==np.amin(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3]):
            ts_4fgl_fsrq_300_1000.append(0.0)
        else:
            ts_4fgl_fsrq_300_1000.append(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i])
    else:
        #print(cat_4fgl_dr3_data['CLASS1'][i])
        continue
print(len(fsrq_4fgl_indices))

bll_4fgl_indices = []
ts_4fgl_bll_300_1000 = []
for i in range(len(cat_4fgl_dr3_data['CLASS1'])):
    if cat_4fgl_dr3_data['CLASS1'][i]==b'bll  ' or cat_4fgl_dr3_data['CLASS1'][i]==b'BLL  ':
        bll_4fgl_indices.append(i)
        if cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i]==np.amin(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3]):
            ts_4fgl_bll_300_1000.append(0.0)
        else:
            ts_4fgl_bll_300_1000.append(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i])
    else:
        #print(cat_4fgl_dr3_data['CLASS1'][i])
        continue
print(len(bll_4fgl_indices))"""
# Out:
# "fsrq_4fgl_indices = []\nts_4fgl_fsrq_300_1000 = []\nfor i in range(len(cat_4fgl_dr3_data['CLASS1'])):\n    if cat_4fgl_dr3_data['CLASS1'][i]==b'fsrq ' or cat_4fgl_dr3_data['CLASS1'][i]==b'FSRQ ':\n        fsrq_4fgl_indices.append(i)\n        if cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i]==np.amin(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3]):\n            ts_4fgl_fsrq_300_1000.append(0.0)\n        else:\n            ts_4fgl_fsrq_300_1000.append(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i])\n    else:\n        #print(cat_4fgl_dr3_data['CLASS1'][i])\n        continue\nprint(len(fsrq_4fgl_indices))\n\nbll_4fgl_indices = []\nts_4fgl_bll_300_1000 = []\nfor i in range(len(cat_4fgl_dr3_data['CLASS1'])):\n    if cat_4fgl_dr3_data['CLASS1'][i]==b'bll  ' or cat_4fgl_dr3_data['CLASS1'][i]==b'BLL  ':\n        bll_4fgl_indices.append(i)\n        if cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i]==np.amin(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3]):\n            ts_4fgl_bll_300_1000.append(0.0)\n        else:\n            ts_4fgl_bll_300_1000.append(cat_4fgl_dr3_data['Sqrt_TS_Band'][:,3][i])\n    else:\n        #print(cat_4fgl_dr3_data['CLASS1'][i])\n        continue\nprint(len(bll_4fgl_indices))"
